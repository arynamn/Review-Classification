# %% [markdown]
# ## FN1: Read File

# %%
def nl_read_file(file_location):
    import pandas as pd
    import re
    if(file_location.endswith('csv')):
        rev_data = pd.read_csv( file_location , engine = 'python')
    elif (file_location.endswith('tsv')):
        rev_data = pd.read_csv( file_location , engine = 'python' ,sep = '\t')
    str_list = []
    for item in rev_data['Review']:
        item = item.lower()
        item= re.sub(r'[^\w\s\']','',item)
        str_list.append(item)
    return str_list

# %% [markdown]
# ## FN2: Tokenizer

# %%
def nl_tokenize(str_list):
    import nltk
    from nltk.corpus import stopwords
    
    filtered_list = []
    filtered_tokens = []
    stop_words=set(stopwords.words("english"))
    for strings in str_list:
        temp_str = nltk.tokenize.word_tokenize(strings)
        temp_tokens = [token for token in temp_str if token not in stop_words]
        filtered_list.append( temp_tokens )
        filtered_tokens = filtered_tokens + temp_tokens
        
    return  {'filtered_list': filtered_list, 'filtered_tokens' : filtered_tokens}

# %% [markdown]
# ## FN3 Pre-Processing

# %%
def nl_pre_process( unprocessed_data ):
    
    (filtered_list , filtered_tokens) = (unprocessed_data['filtered_list'] , unprocessed_data['filtered_tokens'])
    
    import nltk
    from nltk.corpus import stopwords
    from nltk.tag import StanfordPOSTagger
    from nltk.corpus import wordnet
    from nltk.stem.wordnet import WordNetLemmatizer
    
    stanford_dir = "D:\EnvVariables\stanford-postagger-full-2018-10-16"
    modelfile = stanford_dir+"\models\english-bidirectional-distsim.tagger"
    jarfile=stanford_dir+"\stanford-postagger.jar"
    
    tag_dictionary = {"J": wordnet.ADJ,
                      "N": wordnet.NOUN,
                      "V": wordnet.VERB,
                      "R": wordnet.ADV}
    def get_wordnet_pos(tag):
        if tag in tag_dictionary.keys():
            return tag_dictionary[tag]
        else:
            return tag_dictionary['N'] 

    tagger=StanfordPOSTagger( model_filename=modelfile, path_to_jar=jarfile )
    tagged_words = tagger.tag( filtered_tokens )
    
    lem = WordNetLemmatizer()

    lemmatized_words = []

    for w in tagged_words:
        x =  lem.lemmatize(w[0],get_wordnet_pos(w[1][0]))
        lemmatized_words.append((x,w[1]))

    tag_list = []
    index = 0
    for lists in filtered_list:
        length_l = len(lists) + index - 1
        temp = []
        for i in range(index,length_l + 1):
            temp.append(lemmatized_words[i])
        tag_list.append(temp)
        index = length_l + 1
        
        
    return { 'lemmatized_words' : lemmatized_words ,'tag_list' : tag_list }

# %% [markdown]
# ## FN4: Feature Selector

# %%
def nl_feature_filter (prc_data , number_of_features):
    all_nouns = []
    for tuples in prc_data['lemmatized_words']:
        if tuples[1].startswith('NN'):
            all_nouns.append(tuples[0])
    features = []
    from nltk.probability import FreqDist
    fdist = FreqDist(all_nouns)
    for item in fdist.most_common(number_of_features):
        features.append(item[0])
    
    return features

# %% [markdown]
# ## FN5: Orientation Word

# %%
def nl_orientation(input_word, pos_type):
    from nltk.corpus import wordnet
    from nltk.corpus import sentiwordnet
    
    word_synset = wordnet.synsets(input_word)
    orientation_score = 0
    if(len(word_synset) != 0):
        for element in word_synset:
            word=element.name()
            orientation = sentiwordnet.senti_synset(word)
            orientation_score = orientation_score + (orientation.pos_score() - orientation.neg_score())
    return orientation_score

# %% [markdown]
# ## FN6: Orientation Group Of Words

# %%
def nl_orientation_phrase(input_words):
    negative_words = ['not','isn\'t','don\'t','n\'t']
    negator,orient,orient_exact = 0,0,0
    
    for words in input_words:
        word = words[0]
        pos_type = words[0][1]
        if word in negative_words:
            negator = 1
        else:
            temp_val = nl_orientation(word , pos_type.lower())
            orient_exact = orient_exact + temp_val
            if temp_val > 0:
                orient = orient + 1
            elif temp_val < 0:
                orient = orient - 1
        
    return_value = 0          
    if orient > 0:
        return_value = 1
    elif orient < 0:
        return_value = -1
    else:
        if orient_exact > 0:
            return_value = 1
        elif orient_exact < 0:
            return_value = -1
        else:
            return_value = 0
    
    if negator == 0:
        return return_value
    else:
        return return_value * -1

# %% [markdown]
# ## FN7: Review Classifier

# %%
def nl_review_classifier( str_list, unprc_data, prc_data, features ):

    from nltk.corpus import wordnet

    filtered_list =  unprc_data['filtered_list']
    tag_list      =  prc_data['tag_list']


    opinion_dictionary = {}
    opinion_dictionary_tagged = {}
    feature_summary= {}

    for feature in features:
        opinion_dictionary[feature] = {}
        opinion_dictionary_tagged[feature] = []
        feature_summary[feature] = {}
        feature_summary[feature]['total_count'] = 0
        feature_summary[feature]['positive_count'] = 0
        feature_summary[feature]['negative_count'] = 0
        feature_summary[feature]['positive_reviews'] = []
        feature_summary[feature]['negative_reviews'] = []
        feature_summary[feature]['positive_reviews_tokens'] = []
        feature_summary[feature]['negative_reviews_tokens'] = []

    for i in range(len(filtered_list)):
        common_feature = list(set(filtered_list[i]).intersection(features))
        for ele in common_feature:

            index = filtered_list[i].index(ele)
            temp_str = ''
            temp_tuple = []
            feature_summary[ele]['total_count'] = feature_summary[ele]['total_count'] + 1

            for j in range(index-2, index+3):
                if j >= 0  and j < len(tag_list[i]):
                    if tag_list[i][j][1].startswith(('JJ','RB','VB')):
                        temp_str = temp_str + tag_list[i][j][0] + ' '
                        temp_tuple.append(tag_list[i][j])

            if temp_str != '':
                temp_orient = nl_orientation_phrase(temp_tuple)
                opinion_dictionary[ele][temp_str] = temp_orient

                if temp_orient == 1:
                    feature_summary[ele]['positive_count'] = feature_summary[ele]['positive_count'] + 1
                    feature_summary[ele]['positive_reviews'].append(str_list[i])
                    feature_summary[ele]['positive_reviews_tokens'].append(temp_tuple)

                if temp_orient == -1:
                    feature_summary[ele]['negative_count'] = feature_summary[ele]['negative_count'] + 1
                    feature_summary[ele]['negative_reviews'].append(str_list[i])
                    feature_summary[ele]['negative_reviews_tokens'].append(temp_tuple)

                opinion_dictionary_tagged[ele].append(temp_tuple)

    final_data = {'opinion_dictionary' : opinion_dictionary ,'opinion_dictionary_tagged' : opinion_dictionary_tagged 
                      ,'feature_summary' : feature_summary }
    return final_data

# %% [markdown]
# ## FN8: Statistical Data Print

# %%
def stats_calc(data):
    feature_summary = data['feature_summary']
    for item in feature_summary:
        print('\nFEATURE : ',item)
        if feature_summary[item]['total_count'] != 0:
            pos_per = feature_summary[item]['positive_count']/feature_summary[item]['total_count']
            neg_per = feature_summary[item]['negative_count']/feature_summary[item]['total_count']
            miss_per = 1 - (pos_per + neg_per)
            print('    Total Reviews       : ', feature_summary[item]['total_count'])
            print('    Positive Reviews    : ', '%.3f'%pos_per ,'%')
            print('    Negative Reviews    : ', '%.3f'%neg_per ,'%')
            print('    Unclassified Reviews: ', '%.3f'%miss_per,'%')
        else:
            print('    Error in Feature Finding ')

# %% [markdown]
# ## FN9: Function Executer

# %%
def review_classification(input):
    string_data         = nl_read_file(input)
    tokenized_data      = nl_tokenize(string_data)
    processed_data      = nl_pre_process(tokenized_data)
    selected_feature    = nl_feature_filter(processed_data,50)
    result              = nl_review_classifier( string_data, tokenized_data , processed_data ,selected_feature )
    return result

# %% [markdown]
# ## Driver Code

# %%
input_add = "C:/Reviews/2amznokia.csv"
review = review_classification(input_add)

# %%
string_data         = nl_read_file(input_add)
tokenized_data      = nl_tokenize(string_data)
processed_data      = nl_pre_process(tokenized_data)

# %%
processed_data
# Out:
# {'lemmatized_words': [('build', 'VB'),
#   ('quality', 'NN'),
#   ('premium', 'NN'),
#   ('look', 'VBG'),
#   ('compact', 'JJ'),
#   ('design', 'NN'),
#   ('fingerprint', 'NN'),
#   ('sensor', 'NN'),
#   ('fast', 'RB'),
#   ('responsive', 'JJ'),
#   ('camera', 'NN'),
#   ('performance', 'NN'),
#   ('decent', 'JJ'),
#   ('664', 'CD'),
#   ('gb', 'NN'),
#   ('variant', 'NN'),
#   ('already', 'RB'),
#   ('update', 'VBN'),
#   ('android', 'NN'),
#   ('pie', 'NN'),
#   ('9', 'CD'),
#   ('nice', 'JJ'),
#   ('experience', 'NN'),
#   ('ðÿðÿðÿðÿðÿðÿ', 'NN'),
#   ('camera', 'NN'),
#   ('mark', 'NN'),
#   ('worry', 'VBP'),
#   ('happy', 'JJ'),
#   ('purchase', 'NN'),
#   ('good', 'JJ'),
#   ('brand', 'NN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('product', 'NN'),
#   ('use', 'VBD'),
#   ('almost', 'RB'),
#   ('every', 'DT'),
#   ('brand', 'NN'),
#   ('last', 'JJ'),
#   ('4', 'CD'),
#   ('5', 'CD'),
#   ('year', 'NNS'),
#   ('last', 'JJ'),
#   ('feel', 'NN'),
#   ("'m", 'VBP'),
#   ('back', 'JJ'),
#   ('home', 'NN'),
#   ('long', 'JJ'),
#   ('journey', 'NN'),
#   ('best', 'RB'),
#   ('build', 'VBN'),
#   ('quality', 'NN'),
#   ('best', 'JJS'),
#   ('camerabut', 'NN'),
#   ('use', 'NN'),
#   ('gcam', 'NN'),
#   ('nice', 'JJ'),
#   ('design', 'NN'),
#   ('perfect', 'JJ'),
#   ('size', 'NN'),
#   ('nice', 'JJ'),
#   ('display', 'NN'),
#   ('good', 'JJ'),
#   ('performance', 'NN'),
#   ('snapdragon', 'NN'),
#   ('636', 'CD'),
#   ('nokia', 'NN'),
#   ('far', 'RB'),
#   ('fast', 'JJR'),
#   ('n', 'NN'),
#   ('good', 'JJR'),
#   ('respect', 'NN'),
#   ('snapdragon', 'FW'),
#   ('660aie', 'FW'),
#   ('processor', 'NN'),
#   ('xiaomi', 'FW'),
#   ('mi', 'FW'),
#   ('ã', 'FW'),
#   ('2', 'CD'),
#   ('redmi', 'NNS'),
#   ('note', 'VBP'),
#   ('7', 'NNS'),
#   ('7', 'CD'),
#   ('use', 'NN'),
#   ('phone', 'NNS'),
#   ("'m", 'VBP'),
#   ('talk', 'VBG'),
#   ('exactly', 'RB'),
#   ('experience', 'NN'),
#   ('practically', 'RB'),
#   ('real', 'JJ'),
#   ('life', 'NN'),
#   ('moreover', 'RB'),
#   ('48mp', 'JJ'),
#   ('camera', 'NN'),
#   ('redmi', 'NN'),
#   ('note', 'NN'),
#   ('7pro', 'NN'),
#   ('incomparable', 'JJ'),
#   ('nokia', 'NN'),
#   ("'s", 'POS'),
#   ('16mp', 'JJ'),
#   ('use', 'VBG'),
#   ('gcam', 'NN'),
#   ('even', 'RB'),
#   ('old', 'JJR'),
#   ('nokia', 'JJ'),
#   ('61non', 'NN'),
#   ('plus', 'CC'),
#   ('model', 'NN'),
#   ('beat', 'VBZ'),
#   ('camera', 'NN'),
#   ('note', 'NN'),
#   ('7', 'CD'),
#   ('pro', 'JJ'),
#   ('front', 'JJ'),
#   ('rear', 'NN'),
#   ('suggest', 'VBP'),
#   ("n't", 'RB'),
#   ('even', 'RB'),
#   ('hope', 'VB'),
#   ('bring', 'VB'),
#   ('note7', 'JJ'),
#   ('pro', 'NN'),
#   ("'s", 'POS'),
#   ('gimmick', 'NN'),
#   ('48mp', 'NN'),
#   ('near', 'IN'),
#   ('nokia', 'FW'),
#   ('61plus', 'FW'),
#   ('everything', 'NN'),
#   ('perfect', 'JJ'),
#   ('phone', 'NN'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('deal', 'NN'),
#   ('breaker', 'NN'),
#   ('many', 'JJ'),
#   ('youth', 'NNS'),
#   ('charge', 'VBP'),
#   ('twice', 'RB'),
#   ('daypubg', 'NN'),
#   ("'s", 'POS'),
#   ("'m", 'VBP'),
#   ('reduce', 'VBG'),
#   ('one', 'CD'),
#   ('ðÿœÿ', 'NN'),
#   ("'s", 'VBZ'),
#   ('quite', 'RB'),
#   ('easy', 'JJ'),
#   ('manage', 'VBP'),
#   ('one', 'CD'),
#   ('day', 'NN'),
#   ('usage', 'NN'),
#   ('previously', 'RB'),
#   ('use', 'VBP'),
#   ('iphone', 'NN'),
#   ('7', 'CD'),
#   ("n't", 'RB'),
#   ('know', 'VB'),
#   ('many', 'JJ'),
#   ('costumer', 'NNS'),
#   ('amazon', 'VBP'),
#   ('ruin', 'VBG'),
#   ('good', 'JJ'),
#   ('phone', 'NN'),
#   ('make', 'VBD'),
#   ('change', 'NN'),
#   ('many', 'JJ'),
#   ('people', 'NNS'),
#   ("'s", 'POS'),
#   ('mind', 'NNS'),
#   ('theymany', 'NN'),
#   ('people', 'NNS'),
#   ('leave', 'VBD'),
#   ('nokia', 'FW'),
#   ('61plus', 'FW'),
#   ('best', 'JJS'),
#   ('seller', 'NN'),
#   ('apario', 'FW'),
#   ('amazon', 'FW'),
#   ('alternative', 'JJ'),
#   ('phone', 'NN'),
#   ('suggest', 'VBP'),
#   ('phone', 'NN'),
#   ('everyone', 'NN'),
#   ("n't", 'RB'),
#   ('go', 'VB'),
#   ('wrong', 'JJ'),
#   ("n't", 'RB'),
#   ('trust', 'NN'),
#   ('ill', 'RB'),
#   ('review', 'VBZ'),
#   ('comment', 'NNS'),
#   ('buy', 'VBP'),
#   ('try', 'VB'),
#   ('one', 'PRP'),
#   ('wo', 'MD'),
#   ("n't", 'RB'),
#   ('feel', 'VB'),
#   ('repentant', 'JJ'),
#   ('best', 'RBS'),
#   ('mobile', 'JJ'),
#   ('price', 'NN'),
#   ('stock', 'NN'),
#   ('android', 'NN'),
#   ('package', 'NN'),
#   ('headphone', 'NN'),
#   ('mobile', 'JJ'),
#   ('best', 'RB'),
#   ('good', 'JJ'),
#   ('performance', 'NN'),
#   ('happy', 'JJ'),
#   ('purchase', 'NN'),
#   ('ðÿðÿðÿ', 'NN'),
#   ('get', 'VBD'),
#   ('11999', 'CD'),
#   ('prime', 'JJ'),
#   ('day', 'NN'),
#   ('worths', 'VBZ'),
#   ('lovely', 'JJ'),
#   ('camera', 'NN'),
#   ('performance', 'NN'),
#   ('doubt', 'NN'),
#   ('sd636', 'NN'),
#   ('good', 'JJ'),
#   ('ram', 'NN'),
#   ('managementi', 'FW'),
#   ('dont', 'FW'),
#   ('know', 'VB'),
#   ('people', 'NNS'),
#   ('like', 'VBG'),
#   ('damn', 'RB'),
#   ('good', 'JJ'),
#   ('nokia', 'NNS'),
#   ('shut', 'VBP'),
#   ('shop', 'NN'),
#   ('go', 'VBG'),
#   ('return', 'NN'),
#   ('piece', 'NN'),
#   ('crap', 'NN'),
#   ('earlier', 'RBR'),
#   ('iphone', 'FW'),
#   ('5', 'FW'),
#   ('5', 'CD'),
#   ('mp', 'NN'),
#   ('camera', 'NN'),
#   ('photo', 'NNS'),
#   ('take', 'VBN'),
#   ('phone', 'NN'),
#   ('much', 'RB'),
#   ('much', 'RB'),
#   ('good', 'JJR'),
#   ('12', 'CD'),
#   ('mp', 'NN'),
#   ('phone', 'NN'),
#   ('please', 'VBP'),
#   ('donot', 'JJ'),
#   ('buy', 'NN'),
#   ('phone', 'NN'),
#   ('take', 'VBP'),
#   ('lot', 'NN'),
#   ('photo', 'NNS'),
#   ('phone', 'NN'),
#   ('unfortunately', 'RB'),
#   ('ca', 'MD'),
#   ("n't", 'RB'),
#   ('return', 'VB'),
#   ('price', 'NN'),
#   ('r', 'NNS'),
#   ('11999', 'CD'),
#   ('get', 'VBD'),
#   ('6', 'CD'),
#   ('gb', 'NN'),
#   ('ram', 'NN'),
#   ('usbc', 'NN'),
#   ('decent', 'JJ'),
#   ('camera', 'NN'),
#   ('smooth', 'NN'),
#   ('performance', 'NN'),
#   ('experience', 'VBD'),
#   ('lad', 'NN'),
#   ('heavy', 'JJ'),
#   ('gaming', 'NN'),
#   ('hd', 'NN'),
#   ('video', 'NN'),
#   ('playback', 'NN'),
#   ('overall', 'JJ'),
#   ('awesome', 'JJ'),
#   ('phone', 'NN'),
#   ('dislike', 'NN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('tried', 'JJ'),
#   ('return', 'NN'),
#   ('nokia', 'NN'),
#   ('61', 'CD'),
#   ('plus', 'CC'),
#   ('mobile', 'JJ'),
#   ('phone', 'NN'),
#   ('amazon', 'NN'),
#   ('say', 'VBG'),
#   ('electronic', 'JJ'),
#   ('item', 'NNS'),
#   ('returnable', 'JJ'),
#   ('please', 'VB'),
#   ('purchase', 'NN'),
#   ('online', 'JJ'),
#   ('shopping', 'NN'),
#   ('like', 'IN'),
#   ('flipkart', 'FW'),
#   ('snapdeal', 'FW'),
#   ('etc', 'FW'),
#   ("n't", 'RB'),
#   ('purchase', 'NN'),
#   ('amazon', 'NN'),
#   ('interest', 'VBD'),
#   ('purchasebuy', 'JJ'),
#   ('electronic', 'JJ'),
#   ('item', 'NNS'),
#   ('like', 'IN'),
#   ('mobile', 'JJ'),
#   ('phone', 'NN'),
#   ('laptop', 'NN'),
#   ('etc', 'NN'),
#   ('please', 'VBP'),
#   ('go', 'VB'),
#   ('shopping', 'NN'),
#   ('site', 'NN'),
#   ('like', 'IN'),
#   ('flipkart', 'NN'),
#   ('purchase', 'NN'),
#   ('amazon', 'NN'),
#   ('unappy', 'NN'),
#   ('select', 'VBN'),
#   ('amazon', 'IN'),
#   ('online', 'JJ'),
#   ('shopping', 'NN'),
#   ('purchase', 'NN'),
#   ('mobile', 'JJ'),
#   ('phone', 'NN'),
#   ('nokia', 'NN'),
#   ('61', 'CD'),
#   ('plus', 'CC'),
#   ('6gb', 'JJ'),
#   ('ram', 'NN'),
#   ("n't", 'RB'),
#   ('like', 'IN'),
#   ('mobile', 'JJ'),
#   ('phone', 'NN'),
#   ('cause', 'NN'),
#   ('small', 'JJ'),
#   ('size', 'NN'),
#   ('front', 'JJ'),
#   ('camera', 'NN'),
#   ('photo', 'NN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('night', 'NN'),
#   ('time', 'NN'),
#   ('low', 'JJ'),
#   ('light', 'JJ'),
#   ('time', 'NN'),
#   ('rear', 'JJ'),
#   ('camera', 'NN'),
#   ('also', 'RB'),
#   ('like', 'IN'),
#   ('one', 'CD'),
#   ('thing', 'NNS'),
#   ('take', 'VBG'),
#   ('picture', 'NN'),
#   ('room', 'NN'),
#   ('photo', 'NN'),
#   ('quality', 'NN'),
#   ('come', 'VBG'),
#   ('good', 'JJ'),
#   ('per', 'IN'),
#   ('mention', 'VBN'),
#   ('16', 'CD'),
#   ('mega', 'JJ'),
#   ('pixel', 'NN'),
#   ('camera', 'NN'),
#   ('take', 'VBP'),
#   ('photo', 'JJ'),
#   ('outside', 'JJ'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('really', 'RB'),
#   ('good', 'JJ'),
#   ('mobile', 'JJ'),
#   ('hit', 'VBG'),
#   ('much', 'RB'),
#   ('compare', 'VB'),
#   ('mobile', 'NNS'),
#   ('like', 'IN'),
#   ('samsung', 'FW'),
#   ('vivo', 'FW'),
#   ('oppo', 'FW'),
#   ('bad', 'JJS'),
#   ('phone', 'NN'),
#   ('absolutely', 'RB'),
#   ('rubbish', 'JJ'),
#   ('update', 'VBP'),
#   ('system', 'NN'),
#   ('file', 'NN'),
#   ('1306', 'CD'),
#   ('mb', 'NN'),
#   ('even', 'RB'),
#   ('update', 'VBD'),
#   ('system', 'NN'),
#   ('file', 'NN'),
#   ('twice', 'RB'),
#   ('show', 'VBG'),
#   ('repeated', 'JJ'),
#   ('error', 'NN'),
#   ('could', 'MD'),
#   ("n't", 'RB'),
#   ('update', 'VB'),
#   ('installation', 'NN'),
#   ('problem', 'NN'),
#   ('mobile', 'JJ'),
#   ('phone', 'NN'),
#   ('nokia', 'NN'),
#   ('61', 'CD'),
#   ('plus', 'CC'),
#   ('sad', 'JJ'),
#   ('open', 'JJ'),
#   ('box', 'NN'),
#   ('yesterday', 'NN'),
#   ('night', 'NN'),
#   ('1130am', 'NN'),
#   ('till', 'IN'),
#   ('time', 'NN'),
#   ('update', 'VBP'),
#   ('app', 'FW'),
#   ('whatsapp', 'FW'),
#   ('super', 'JJ'),
#   ('good', 'JJ'),
#   ('phone', 'NN'),
#   ('fast', 'JJ'),
#   ('phone', 'NN'),
#   ('get', 'VBD'),
#   ('nokia', 'NN'),
#   ('61', 'CD'),
#   ('mobile', 'JJ'),
#   ('week', 'NN'),
#   ('back', 'RB'),
#   ('lot', 'RB'),
#   ('heat', 'VBG'),
#   ('issue', 'NN'),
#   ('touch', 'NN'),
#   ('terrible', 'JJ'),
#   ('experience', 'NN'),
#   ('worth', 'JJ'),
#   ('money', 'NN'),
#   ('disappointed', 'JJ'),
#   ('amazon', 'NN'),
#   ('service', 'NNS'),
#   ('well', 'RB'),
#   ('try', 'VBG'),
#   ('place', 'NN'),
#   ('return', 'NN'),
#   ('request', 'NN'),
#   ('couple', 'NN'),
#   ('time', 'NNS'),
#   ('response', 'NN'),
#   ('want', 'VBP'),
#   ('escalate', 'VB'),
#   ('issue', 'NN'),
#   ('next', 'JJ'),
#   ('level', 'NN'),
#   ('purchase', 'VBD'),
#   ('move', 'NN'),
#   ('phone', 'NN'),
#   ('low', 'JJS'),
#   ('price', 'NN'),
#   ('issue', 'NN'),
#   ('use', 'VBG'),
#   ('5', 'CD'),
#   ('6', 'CD'),
#   ('hour', 'NNS'),
#   ('automaticly', 'RB'),
#   ('switche', 'VBP'),
#   ('purchase', 'VBN'),
#   ('3', 'CD'),
#   ('mobile', 'JJ'),
#   ('phone', 'NN'),
#   ('every', 'DT'),
#   ('one', 'CD'),
#   ('get', 'VBG'),
#   ('diffrent', 'JJ'),
#   ('type', 'NN'),
#   ('issue', 'NN'),
#   ('think', 'VBP'),
#   ('phone', 'NN'),
#   ('quality', 'NN'),
#   ('issue', 'NN'),
#   ("'s", 'POS'),
#   ('amozone', 'NN'),
#   ('sale', 'NN'),
#   ('low', 'JJS'),
#   ('price', 'NN'),
#   ('perfect', 'JJ'),
#   ('blend', 'VB'),
#   ('craftsmanship', 'NN'),
#   ('durability', 'NN'),
#   ('nokia', 'NN'),
#   ('61', 'CD'),
#   ('plus', 'CC'),
#   ('gr8', 'CD'),
#   ('device', 'NN'),
#   ('indeed', 'RB'),
#   ('get', 'VBD'),
#   ('12k', 'FW'),
#   ('664gb', 'FW'),
#   ('variant', 'NN'),
#   ('really', 'RB'),
#   ('handy', 'JJ'),
#   ('device', 'NN'),
#   ('think', 'VBD'),
#   ('3050', 'CD'),
#   ('mah', 'NN'),
#   ('battery', 'NN'),
#   ('may', 'MD'),
#   ('seem', 'VB'),
#   ('little', 'JJ'),
#   ('underwhelming', 'JJ'),
#   ('device', 'NN'),
#   ('make', 'NNS'),
#   ('run', 'VBZ'),
#   ('day', 'NN'),
#   ('half', 'NN'),
#   ('moderate', 'JJ'),
#   ('usage', 'NN'),
#   ('one', 'CD'),
#   ('thing', 'NN'),
#   ('second', 'JJ'),
#   ('thought', 'NNS'),
#   ('regard', 'VBG'),
#   ('front', 'JJ'),
#   ('panel', 'NN'),
#   ('bottom', 'NN'),
#   ('brand', 'VBG'),
#   ('chin', 'NN'),
#   ('planning', 'NN'),
#   ('abandon', 'VBP'),
#   ('device', 'NN'),
#   ('bad', 'JJ'),
#   ('idea', 'NN'),
#   ('cuz', 'FW'),
#   ('u', 'FW'),
#   ('get', 'VB'),
#   ('hand', 'NN'),
#   ('device', 'NN'),
#   ('true', 'JJ'),
#   ('flagship', 'NN'),
#   ('killer', 'NN'),
#   ('look', 'VBZ'),
#   ('really', 'RB'),
#   ('premium', 'JJ'),
#   ('able', 'JJ'),
#   ('start', 'NN'),
#   ('mobile', 'JJ'),
#   ('since', 'IN'),
#   ('unpack', 'VBG'),
#   ('box', 'NN'),
#   ('2days', 'NNS'),
#   ('request', 'VBP'),
#   ('take', 'VB'),
#   ('back', 'RP'),
#   ('mobile', 'JJ'),
#   ('bad', 'JJ'),
#   ('experience', 'NN'),
#   ('mobile', 'JJ'),
#   ('come', 'VBD'),
#   ('without', 'IN'),
#   ('software', 'NN'),
#   ('switching', 'NN'),
#   ('mobile', 'JJ'),
#   ('asking', 'NN'),
#   ('system', 'NN'),
#   ('update', 'VBP'),
#   ('download', 'NN'),
#   ('wifi', 'NNS'),
#   ('download', 'NN'),
#   ('complete', 'VBZ'),
#   ('say', 'VBZ'),
#   ('installation', 'NN'),
#   ('problem', 'NN'),
#   ('working', 'NN'),
#   ("'m", 'VBP'),
#   ('unable', 'JJ'),
#   ('use', 'NN'),
#   ("'s", 'POS'),
#   ('start', 'VBG'),
#   ('awesome', 'JJ'),
#   ('phone', 'NN'),
#   ('use', 'VBN'),
#   ('xiomi', 'FW'),
#   ('vivo', 'FW'),
#   ('nothing', 'NN'),
#   ('beat', 'NN'),
#   ('nokia', 'NN'),
#   ("'s", 'POS'),
#   ('quality', 'NN'),
#   ("'s", 'POS'),
#   ('still', 'RB'),
#   ('best', 'RB'),
#   ('handy', 'JJ'),
#   ('mobile', 'JJ'),
#   ('also', 'RB'),
#   ('get', 'VB'),
#   ('earphone', 'NNS'),
#   ('company', 'NNS'),
#   ('stop', 'VBD'),
#   ('give', 'VBG'),
#   ('guy', 'NNS'),
#   ('risk', 'NN'),
#   ('buy', 'NN'),
#   ('productas', 'NNS'),
#   ('receive', 'VBD'),
#   ('totally', 'RB'),
#   ('defective', 'JJ'),
#   ('productit', 'NN'),
#   ('get', 'VBG'),
#   ('heated', 'JJ'),
#   ('charging', 'NN'),
#   ('also', 'RB'),
#   ('get', 'VBG'),
#   ('hangedthe', 'JJ'),
#   ('important', 'JJ'),
#   ('thing', 'NN'),
#   ('accept', 'VBG'),
#   ('pin', 'NN'),
#   ('set', 'NN'),
#   ('phone', 'NN'),
#   ('get', 'VBG'),
#   ('reset', 'JJ'),
#   ('commandthe', 'JJ'),
#   ('command', 'NN'),
#   ('window', 'NN'),
#   ('available', 'JJ'),
#   ('nokia', 'NN'),
#   ('61', 'CD'),
#   ('4gb', 'JJ'),
#   ('ram', 'NN'),
#   ('64', 'CD'),
#   ('gb', 'NN'),
#   ('memory', 'NN'),
#   ('storage', 'NN'),
#   ('61', 'CD'),
#   ('plus', 'CC'),
#   ('nokia', 'NN'),
#   ('drop', 'VBD'),
#   ("'s", 'POS'),
#   ('hardware', 'NN'),
#   ('quality', 'NN'),
#   ('6gb', 'JJ'),
#   ('ram', 'NN'),
#   ('performance', 'NN'),
#   ('degrade', 'VBD'),
#   ('compare', 'VBN'),
#   ('4gb', 'JJ'),
#   ('ram', 'NN'),
#   ('nokia', 'NN'),
#   ('61', 'CD'),
#   ('excellent', 'JJ'),
#   ('phone', 'NN'),
#   ('perfect', 'JJ'),
#   ('serve', 'VBZ'),
#   ('purpose', 'NN'),
#   ('since', 'IN'),
#   ('call', 'VBG'),
#   ('whatsapp', 'JJ'),
#   ('usage', 'NN'),
#   ('happy', 'JJ'),
#   ('performance', 'NN'),
#   ('phone', 'NN'),
#   ('time', 'NN'),
#   ('delivery', 'NN'),
#   ('receive', 'VBD'),
#   ('sealed', 'JJ'),
#   ('box', 'NN'),
#   ('overall', 'JJ'),
#   ('good', 'JJ'),
#   ('experience', 'NN'),
#   ('flipkart', 'NN'),
#   ('seller', 'NN'),
#   ('nokia', 'VBD'),
#   ('another', 'DT'),
#   ('premium', 'NN'),
#   ('product', 'NN'),
#   ('nokia', 'NN'),
#   ('build', 'VBP'),
#   ('quality', 'NN'),
#   ('look', 'VBZ'),
#   ('superb', 'JJ'),
#   ('stock', 'NN'),
#   ('android', 'NN'),
#   ('clean', 'JJ'),
#   ('interface', 'NN'),
#   ('like', 'IN'),
#   ('customise', 'VBN'),
#   ('android', 'NN'),
#   ('interface', 'NNS'),
#   ('add', 'VBZ'),
#   ('bag', 'VBN'),
#   ('amazing', 'JJ'),
#   ('deal', 'NN'),
#   ('prime', 'JJ'),
#   ('day', 'NNS'),
#   ('overall', 'JJ'),
#   ('experience', 'NN'),
#   ('phone', 'NN'),
#   ('awesome', 'JJ'),
#   ('price', 'NN'),
#   ('band', 'NN'),
#   ('thanks', 'NNS'),
#   ('amazon', 'VBP'),
#   ('deliver', 'VBG'),
#   ('day', 'NN'),
#   ('almost', 'RB'),
#   ('hat', 'NNS'),
#   ('great', 'RB'),
#   ('phone', 'VBP'),
#   ('highly', 'RB'),
#   ('handy', 'JJ'),
#   ('fit', 'NNS'),
#   ('well', 'RB'),
#   ('hand', 'VBP'),
#   ('camera', 'NN'),
#   ('good', 'JJ'),
#   ('battery', 'NN'),
#   ('last', 'VBZ'),
#   ('day', 'NN'),
#   ('half', 'JJ'),
#   ('nokia', 'NN'),
#   ('really', 'RB'),
#   ('good', 'JJ'),
#   ('still', 'RB'),
#   ('first', 'JJ'),
#   ('overview', 'NN'),
#   ('product', 'NN'),
#   ('one', 'CD'),
#   ('word', 'NN'),
#   ("'s", 'POS'),
#   ('classy', 'JJ'),
#   ('premium', 'NN'),
#   ('class', 'NN'),
#   ('metalic', 'JJ'),
#   ('damn', 'NN'),
#   ('sexy', 'JJ'),
#   ('second', 'JJ'),
#   ('thing', 'NN'),
#   ('performance', 'NN'),
#   ('end', 'NN'),
#   ('game', 'NNS'),
#   ('still', 'RB'),
#   ("n't", 'RB'),
#   ('find', 'VBD'),
#   ('single', 'JJ'),
#   ('lagin', 'JJ'),
#   ('one', 'NN'),
#   ("'s", 'POS'),
#   ('buttersmooth', 'NN'),
#   ('creamy', 'JJ'),
#   ('never', 'RB'),
#   ('make', 'VB'),
#   ('u', 'NN'),
#   ('feel', 'NN'),
#   ('like', 'IN'),
#   ('lag', 'NN'),
#   ('hang', 'VBP'),
#   ('issue', 'NN'),
#   ('highly', 'RB'),
#   ('recommend', 'VBD'),
#   ('gamers', 'NNS'),
#   ('never', 'RB'),
#   ('mind', 'VBP'),
#   ('heating', 'NN'),
#   ('issue', 'NN'),
#   ('issue', 'NN'),
#   ('wheb', 'NN'),
#   ('multitasking', 'VBG'),
#   ('play', 'NN'),
#   ('game', 'NNS'),
#   ('2', 'CD'),
#   ('hour', 'NN'),
#   ('battery', 'NN'),
#   ('board', 'NN'),
#   ('start', 'VBZ'),
#   ('heat', 'NN'),
#   ('produce', 'VBP'),
#   ('energysome', 'JJ'),
#   ('mobile', 'NNS'),
#   ('panel', 'NN'),
#   ('wo', 'MD'),
#   ("n't", 'RB'),
#   ('show', 'VB'),
#   ("'s", 'POS'),
#   ('glass', 'NN'),
#   ('make', 'VBD'),
#   ('back', 'JJ'),
#   ('door', 'NN'),
#   ('reflect', 'VBZ'),
#   ('transparently', 'RB'),
#   ('safe', 'JJ'),
#   ('becaus', 'NN'),
#   ("'s", 'POS'),
#   ('store', 'VBG'),
#   ('head', 'NN'),
#   ('inside', 'IN'),
#   ('within', 'IN'),
#   ('2', 'CD'),
#   ('5', 'CD'),
#   ('minute', 'NNS'),
#   ('come', 'VBP'),
#   ('normal', 'JJ'),
#   ('temperature', 'NN'),
#   ('brand', 'NN'),
#   ('spoiler', 'NNS'),
#   ('post', 'VBP'),
#   ('like', 'IN'),
#   ('battery', 'NN'),
#   ('issue', 'NN'),
#   ('heating', 'NN'),
#   ('issue', 'NN'),
#   ('please', 'VBP'),
#   ("n't", 'RB'),
#   ('trust', 'NN'),
#   ('u', 'NN'),
#   ('trust', 'NN'),
#   ('single', 'JJ'),
#   ('common', 'JJ'),
#   ('heat', 'NN'),
#   ('also', 'RB'),
#   ('seem', 'VBZ'),
#   ('like', 'IN'),
#   ('heavy', 'JJ'),
#   ('one', 'CD'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('performance', 'NN'),
#   ('really', 'RB'),
#   ('happy', 'JJ'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('see', 'VBP'),
#   ('use', 'NN'),
#   ('upto', 'NN'),
#   ('10', 'CD'),
#   ('hour', 'NNS'),
#   ('screen', 'NN'),
#   ('upto', 'NN'),
#   ('2', 'CD'),
#   ('3', 'CD'),
#   ('day', 'NNS'),
#   ('idle', 'VBP'),
#   ('charge', 'VBG'),
#   ('flawless', 'JJ'),
#   ('awesome', 'JJ'),
#   ('fully', 'RB'),
#   ('charge', 'VBN'),
#   ('device', 'NN'),
#   ('1hour', 'NN'),
#   ('40', 'CD'),
#   ('minute', 'NNS'),
#   ('mobile', 'JJ'),
#   ('switch', 'VBN'),
#   ('take', 'VBZ'),
#   ('223', 'CD'),
#   ('hour', 'NNS'),
#   ('chargei', 'NNS'),
#   ('mean', 'VBP'),
#   ('quick', 'JJ'),
#   ('charge', 'NN'),
#   ('work', 'VBZ'),
#   ('mobile', 'JJ'),
#   ('turnd', 'NN'),
#   ('try', 'VB'),
#   ('18w', 'FW'),
#   ('charger', 'FW'),
#   ('good', 'JJR'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('one', 'CD'),
#   ('word', 'NN'),
#   ("'s", 'POS'),
#   ('awesome', 'JJ'),
#   ('juice', 'NN'),
#   ('drink', 'NN'),
#   ('fir', 'NN'),
#   ('whole', 'JJ'),
#   ('day', 'NN'),
#   ('camera', 'NN'),
#   ('clearity', 'NN'),
#   ('excited', 'JJ'),
#   ('image', 'NN'),
#   ('shoot', 'VBD'),
#   ('perfect', 'JJ'),
#   ('lighting', 'NN'),
#   ('perfect', 'JJ'),
#   ('balance', 'NN'),
#   ('nearly', 'RB'),
#   ('25', 'CD'),
#   ('mb', 'NN'),
#   ("'s", 'POS'),
#   ('crisp', 'JJ'),
#   ('clear', 'JJ'),
#   ('awesome', 'JJ'),
#   ('picture', 'NN'),
#   ('see', 'VB'),
#   ('detail', 'NNS'),
#   ('everything', 'NN'),
#   ('inever', 'RB'),
#   ('see', 'VBN'),
#   ('type', 'NN'),
#   ('clear', 'JJ'),
#   ('picture', 'NN'),
#   ('mobile', 'JJ'),
#   ('camera', 'NN'),
#   ('low', 'JJ'),
#   ('light', 'NN'),
#   ("'s", 'POS'),
#   ('damn', 'NN'),
#   ('bad', 'JJS'),
#   ('ever', 'RB'),
#   ('camera', 'NN'),
#   ('reason', 'NN'),
#   ('hardware', 'NN'),
#   ("'s", 'POS'),
#   ('software', 'NN'),
#   ('soon', 'RB'),
#   ('solve', 'VBD'),
#   ('thus', 'RB'),
#   ('world', 'NN'),
#   ('bi', 'IN'),
#   ('perfect', 'JJ'),
#   ('phone', 'NN'),
#   ('range', 'NN'),
#   ("n't", 'RB'),
#   ('expect', 'VB'),
#   ('mobile', 'JJ'),
#   ('overall', 'NN'),
#   ("'s", 'POS'),
#   ('best', 'JJS'),
#   ('steal', 'VBP'),
#   ('awesome', 'JJ'),
#   ('stuff', 'NN'),
#   ('ever', 'RB'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ("'s", 'POS'),
#   ('unimaginable', 'JJ'),
#   ('go', 'NN'),
#   ("'ve", 'VBP'),
#   ('use', 'VBN'),
#   ('phone', 'NN'),
#   ('almost', 'RB'),
#   ('month', 'NN'),
#   ('would', 'MD'),
#   ('certainly', 'RB'),
#   ('recommend', 'VBN'),
#   ('gaming', 'NN'),
#   ('due', 'JJ'),
#   ('heating', 'NN'),
#   ('issue', 'NNS'),
#   ('battery', 'NN'),
#   ('drain', 'NN'),
#   ('camera', 'NN'),
#   ('light', 'VBD'),
#   ('ui', 'NN'),
#   ('also', 'RB'),
#   ('amazing', 'JJ'),
#   ("'s", 'POS'),
#   ('little', 'JJ'),
#   ('problem', 'NN'),
#   ('installation', 'NN'),
#   ('process', 'NN'),
#   ('phone', 'VBP'),
#   ("n't", 'RB'),
#   ('complete', 'JJ'),
#   ('unless', 'IN'),
#   ('really', 'RB'),
#   ('fast', 'JJ'),
#   ('internet', 'NN'),
#   ('connection', 'NN'),
#   ('battery', 'NN'),
#   ('performance', 'NN'),
#   ('bad', 'JJ'),
#   ('charged', 'JJ'),
#   ('use', 'NN'),
#   ('23', 'CD'),
#   ('day', 'NNS'),
#   ('use', 'VBP'),
#   ('wisely', 'RB'),
#   ('require', 'VBN'),
#   ('stuff', 'NNS'),
#   ('without', 'IN'),
#   ('play', 'VBG'),
#   ...],
#  'tag_list': [[('build', 'VB'),
#    ('quality', 'NN'),
#    ('premium', 'NN'),
#    ('look', 'VBG')],
#   [('compact', 'JJ'),
#    ('design', 'NN'),
#    ('fingerprint', 'NN'),
#    ('sensor', 'NN'),
#    ('fast', 'RB'),
#    ('responsive', 'JJ')],
#   [('camera', 'NN'), ('performance', 'NN'), ('decent', 'JJ')],
#   [('664', 'CD'),
#    ('gb', 'NN'),
#    ('variant', 'NN'),
#    ('already', 'RB'),
#    ('update', 'VBN'),
#    ('android', 'NN'),
#    ('pie', 'NN'),
#    ('9', 'CD')],
#   [('nice', 'JJ'), ('experience', 'NN'), ('ðÿðÿðÿðÿðÿðÿ', 'NN')],
#   [('camera', 'NN'), ('mark', 'NN')],
#   [('worry', 'VBP'),
#    ('happy', 'JJ'),
#    ('purchase', 'NN'),
#    ('good', 'JJ'),
#    ('brand', 'NN'),
#    ('quality', 'NN')],
#   [('good', 'JJ'),
#    ('product', 'NN'),
#    ('use', 'VBD'),
#    ('almost', 'RB'),
#    ('every', 'DT'),
#    ('brand', 'NN'),
#    ('last', 'JJ'),
#    ('4', 'CD'),
#    ('5', 'CD'),
#    ('year', 'NNS'),
#    ('last', 'JJ'),
#    ('feel', 'NN'),
#    ("'m", 'VBP'),
#    ('back', 'JJ'),
#    ('home', 'NN'),
#    ('long', 'JJ'),
#    ('journey', 'NN'),
#    ('best', 'RB'),
#    ('build', 'VBN'),
#    ('quality', 'NN'),
#    ('best', 'JJS'),
#    ('camerabut', 'NN'),
#    ('use', 'NN'),
#    ('gcam', 'NN'),
#    ('nice', 'JJ'),
#    ('design', 'NN'),
#    ('perfect', 'JJ'),
#    ('size', 'NN'),
#    ('nice', 'JJ'),
#    ('display', 'NN'),
#    ('good', 'JJ'),
#    ('performance', 'NN'),
#    ('snapdragon', 'NN'),
#    ('636', 'CD'),
#    ('nokia', 'NN'),
#    ('far', 'RB'),
#    ('fast', 'JJR'),
#    ('n', 'NN'),
#    ('good', 'JJR'),
#    ('respect', 'NN'),
#    ('snapdragon', 'FW'),
#    ('660aie', 'FW'),
#    ('processor', 'NN'),
#    ('xiaomi', 'FW'),
#    ('mi', 'FW'),
#    ('ã', 'FW'),
#    ('2', 'CD'),
#    ('redmi', 'NNS'),
#    ('note', 'VBP'),
#    ('7', 'NNS'),
#    ('7', 'CD'),
#    ('use', 'NN'),
#    ('phone', 'NNS'),
#    ("'m", 'VBP'),
#    ('talk', 'VBG'),
#    ('exactly', 'RB'),
#    ('experience', 'NN'),
#    ('practically', 'RB'),
#    ('real', 'JJ'),
#    ('life', 'NN'),
#    ('moreover', 'RB'),
#    ('48mp', 'JJ'),
#    ('camera', 'NN'),
#    ('redmi', 'NN'),
#    ('note', 'NN'),
#    ('7pro', 'NN'),
#    ('incomparable', 'JJ'),
#    ('nokia', 'NN'),
#    ("'s", 'POS'),
#    ('16mp', 'JJ'),
#    ('use', 'VBG'),
#    ('gcam', 'NN'),
#    ('even', 'RB'),
#    ('old', 'JJR'),
#    ('nokia', 'JJ'),
#    ('61non', 'NN'),
#    ('plus', 'CC'),
#    ('model', 'NN'),
#    ('beat', 'VBZ'),
#    ('camera', 'NN'),
#    ('note', 'NN'),
#    ('7', 'CD'),
#    ('pro', 'JJ'),
#    ('front', 'JJ'),
#    ('rear', 'NN'),
#    ('suggest', 'VBP'),
#    ("n't", 'RB'),
#    ('even', 'RB'),
#    ('hope', 'VB'),
#    ('bring', 'VB'),
#    ('note7', 'JJ'),
#    ('pro', 'NN'),
#    ("'s", 'POS'),
#    ('gimmick', 'NN'),
#    ('48mp', 'NN'),
#    ('near', 'IN'),
#    ('nokia', 'FW'),
#    ('61plus', 'FW'),
#    ('everything', 'NN'),
#    ('perfect', 'JJ'),
#    ('phone', 'NN'),
#    ('battery', 'NN'),
#    ('life', 'NN'),
#    ('deal', 'NN'),
#    ('breaker', 'NN'),
#    ('many', 'JJ'),
#    ('youth', 'NNS'),
#    ('charge', 'VBP'),
#    ('twice', 'RB'),
#    ('daypubg', 'NN'),
#    ("'s", 'POS'),
#    ("'m", 'VBP'),
#    ('reduce', 'VBG'),
#    ('one', 'CD'),
#    ('ðÿœÿ', 'NN'),
#    ("'s", 'VBZ'),
#    ('quite', 'RB'),
#    ('easy', 'JJ'),
#    ('manage', 'VBP'),
#    ('one', 'CD'),
#    ('day', 'NN'),
#    ('usage', 'NN'),
#    ('previously', 'RB'),
#    ('use', 'VBP'),
#    ('iphone', 'NN'),
#    ('7', 'CD'),
#    ("n't", 'RB'),
#    ('know', 'VB'),
#    ('many', 'JJ'),
#    ('costumer', 'NNS'),
#    ('amazon', 'VBP'),
#    ('ruin', 'VBG'),
#    ('good', 'JJ'),
#    ('phone', 'NN'),
#    ('make', 'VBD'),
#    ('change', 'NN'),
#    ('many', 'JJ'),
#    ('people', 'NNS'),
#    ("'s", 'POS'),
#    ('mind', 'NNS'),
#    ('theymany', 'NN'),
#    ('people', 'NNS'),
#    ('leave', 'VBD'),
#    ('nokia', 'FW'),
#    ('61plus', 'FW'),
#    ('best', 'JJS'),
#    ('seller', 'NN'),
#    ('apario', 'FW'),
#    ('amazon', 'FW'),
#    ('alternative', 'JJ'),
#    ('phone', 'NN'),
#    ('suggest', 'VBP'),
#    ('phone', 'NN'),
#    ('everyone', 'NN'),
#    ("n't", 'RB'),
#    ('go', 'VB'),
#    ('wrong', 'JJ'),
#    ("n't", 'RB'),
#    ('trust', 'NN'),
#    ('ill', 'RB'),
#    ('review', 'VBZ'),
#    ('comment', 'NNS'),
#    ('buy', 'VBP'),
#    ('try', 'VB'),
#    ('one', 'PRP'),
#    ('wo', 'MD'),
#    ("n't", 'RB'),
#    ('feel', 'VB'),
#    ('repentant', 'JJ')],
#   [('best', 'RBS'), ('mobile', 'JJ'), ('price', 'NN')],
#   [('stock', 'NN'), ('android', 'NN')],
#   [('package', 'NN'), ('headphone', 'NN')],
#   [('mobile', 'JJ'), ('best', 'RB')],
#   [('good', 'JJ'),
#    ('performance', 'NN'),
#    ('happy', 'JJ'),
#    ('purchase', 'NN'),
#    ('ðÿðÿðÿ', 'NN')],
#   [('get', 'VBD'),
#    ('11999', 'CD'),
#    ('prime', 'JJ'),
#    ('day', 'NN'),
#    ('worths', 'VBZ'),
#    ('lovely', 'JJ'),
#    ('camera', 'NN'),
#    ('performance', 'NN'),
#    ('doubt', 'NN'),
#    ('sd636', 'NN'),
#    ('good', 'JJ'),
#    ('ram', 'NN'),
#    ('managementi', 'FW'),
#    ('dont', 'FW'),
#    ('know', 'VB'),
#    ('people', 'NNS'),
#    ('like', 'VBG'),
#    ('damn', 'RB'),
#    ('good', 'JJ')],
#   [('nokia', 'NNS'),
#    ('shut', 'VBP'),
#    ('shop', 'NN'),
#    ('go', 'VBG'),
#    ('return', 'NN'),
#    ('piece', 'NN'),
#    ('crap', 'NN')],
#   [('earlier', 'RBR'),
#    ('iphone', 'FW'),
#    ('5', 'FW'),
#    ('5', 'CD'),
#    ('mp', 'NN'),
#    ('camera', 'NN'),
#    ('photo', 'NNS'),
#    ('take', 'VBN'),
#    ('phone', 'NN'),
#    ('much', 'RB'),
#    ('much', 'RB'),
#    ('good', 'JJR'),
#    ('12', 'CD'),
#    ('mp', 'NN'),
#    ('phone', 'NN'),
#    ('please', 'VBP'),
#    ('donot', 'JJ'),
#    ('buy', 'NN'),
#    ('phone', 'NN'),
#    ('take', 'VBP'),
#    ('lot', 'NN'),
#    ('photo', 'NNS'),
#    ('phone', 'NN')],
#   [('unfortunately', 'RB'), ('ca', 'MD'), ("n't", 'RB'), ('return', 'VB')],
#   [('price', 'NN'),
#    ('r', 'NNS'),
#    ('11999', 'CD'),
#    ('get', 'VBD'),
#    ('6', 'CD'),
#    ('gb', 'NN'),
#    ('ram', 'NN')],
#   [('usbc', 'NN'),
#    ('decent', 'JJ'),
#    ('camera', 'NN'),
#    ('smooth', 'NN'),
#    ('performance', 'NN'),
#    ('experience', 'VBD'),
#    ('lad', 'NN'),
#    ('heavy', 'JJ'),
#    ('gaming', 'NN'),
#    ('hd', 'NN'),
#    ('video', 'NN'),
#    ('playback', 'NN'),
#    ('overall', 'JJ'),
#    ('awesome', 'JJ'),
#    ('phone', 'NN')],
#   [('dislike', 'NN'),
#    ('quality', 'NN'),
#    ('good', 'JJ'),
#    ('tried', 'JJ'),
#    ('return', 'NN'),
#    ('nokia', 'NN'),
#    ('61', 'CD'),
#    ('plus', 'CC'),
#    ('mobile', 'JJ'),
#    ('phone', 'NN'),
#    ('amazon', 'NN'),
#    ('say', 'VBG'),
#    ('electronic', 'JJ'),
#    ('item', 'NNS'),
#    ('returnable', 'JJ'),
#    ('please', 'VB'),
#    ('purchase', 'NN'),
#    ('online', 'JJ'),
#    ('shopping', 'NN'),
#    ('like', 'IN'),
#    ('flipkart', 'FW'),
#    ('snapdeal', 'FW'),
#    ('etc', 'FW'),
#    ("n't", 'RB'),
#    ('purchase', 'NN'),
#    ('amazon', 'NN'),
#    ('interest', 'VBD'),
#    ('purchasebuy', 'JJ'),
#    ('electronic', 'JJ'),
#    ('item', 'NNS'),
#    ('like', 'IN'),
#    ('mobile', 'JJ'),
#    ('phone', 'NN'),
#    ('laptop', 'NN'),
#    ('etc', 'NN'),
#    ('please', 'VBP'),
#    ('go', 'VB'),
#    ('shopping', 'NN'),
#    ('site', 'NN'),
#    ('like', 'IN'),
#    ('flipkart', 'NN'),
#    ('purchase', 'NN'),
#    ('amazon', 'NN'),
#    ('unappy', 'NN'),
#    ('select', 'VBN'),
#    ('amazon', 'IN'),
#    ('online', 'JJ'),
#    ('shopping', 'NN'),
#    ('purchase', 'NN'),
#    ('mobile', 'JJ'),
#    ('phone', 'NN'),
#    ('nokia', 'NN'),
#    ('61', 'CD'),
#    ('plus', 'CC'),
#    ('6gb', 'JJ'),
#    ('ram', 'NN'),
#    ("n't", 'RB'),
#    ('like', 'IN'),
#    ('mobile', 'JJ'),
#    ('phone', 'NN'),
#    ('cause', 'NN'),
#    ('small', 'JJ'),
#    ('size', 'NN'),
#    ('front', 'JJ'),
#    ('camera', 'NN'),
#    ('photo', 'NN'),
#    ('quality', 'NN'),
#    ('good', 'JJ'),
#    ('night', 'NN'),
#    ('time', 'NN'),
#    ('low', 'JJ'),
#    ('light', 'JJ'),
#    ('time', 'NN'),
#    ('rear', 'JJ'),
#    ('camera', 'NN'),
#    ('also', 'RB'),
#    ('like', 'IN'),
#    ('one', 'CD'),
#    ('thing', 'NNS'),
#    ('take', 'VBG'),
#    ('picture', 'NN'),
#    ('room', 'NN'),
#    ('photo', 'NN'),
#    ('quality', 'NN'),
#    ('come', 'VBG'),
#    ('good', 'JJ'),
#    ('per', 'IN'),
#    ('mention', 'VBN'),
#    ('16', 'CD'),
#    ('mega', 'JJ'),
#    ('pixel', 'NN'),
#    ('camera', 'NN'),
#    ('take', 'VBP'),
#    ('photo', 'JJ'),
#    ('outside', 'JJ'),
#    ('picture', 'NN'),
#    ('quality', 'NN'),
#    ('really', 'RB'),
#    ('good', 'JJ'),
#    ('mobile', 'JJ'),
#    ('hit', 'VBG'),
#    ('much', 'RB'),
#    ('compare', 'VB'),
#    ('mobile', 'NNS'),
#    ('like', 'IN'),
#    ('samsung', 'FW'),
#    ('vivo', 'FW'),
#    ('oppo', 'FW')],
#   [('bad', 'JJS'), ('phone', 'NN')],
#   [('absolutely', 'RB'),
#    ('rubbish', 'JJ'),
#    ('update', 'VBP'),
#    ('system', 'NN'),
#    ('file', 'NN'),
#    ('1306', 'CD'),
#    ('mb', 'NN'),
#    ('even', 'RB'),
#    ('update', 'VBD'),
#    ('system', 'NN'),
#    ('file', 'NN'),
#    ('twice', 'RB'),
#    ('show', 'VBG'),
#    ('repeated', 'JJ'),
#    ('error', 'NN'),
#    ('could', 'MD'),
#    ("n't", 'RB'),
#    ('update', 'VB'),
#    ('installation', 'NN'),
#    ('problem', 'NN')],
#   [('mobile', 'JJ'),
#    ('phone', 'NN'),
#    ('nokia', 'NN'),
#    ('61', 'CD'),
#    ('plus', 'CC')],
#   [('sad', 'JJ'),
#    ('open', 'JJ'),
#    ('box', 'NN'),
#    ('yesterday', 'NN'),
#    ('night', 'NN'),
#    ('1130am', 'NN'),
#    ('till', 'IN'),
#    ('time', 'NN'),
#    ('update', 'VBP'),
#    ('app', 'FW'),
#    ('whatsapp', 'FW')],
#   [('super', 'JJ'),
#    ('good', 'JJ'),
#    ('phone', 'NN'),
#    ('fast', 'JJ'),
#    ('phone', 'NN')],
#   [('get', 'VBD'),
#    ('nokia', 'NN'),
#    ('61', 'CD'),
#    ('mobile', 'JJ'),
#    ('week', 'NN'),
#    ('back', 'RB'),
#    ('lot', 'RB'),
#    ('heat', 'VBG'),
#    ('issue', 'NN'),
#    ('touch', 'NN'),
#    ('terrible', 'JJ'),
#    ('experience', 'NN')],
#   [('worth', 'JJ'),
#    ('money', 'NN'),
#    ('disappointed', 'JJ'),
#    ('amazon', 'NN'),
#    ('service', 'NNS'),
#    ('well', 'RB'),
#    ('try', 'VBG'),
#    ('place', 'NN'),
#    ('return', 'NN'),
#    ('request', 'NN'),
#    ('couple', 'NN'),
#    ('time', 'NNS'),
#    ('response', 'NN')],
#   [('want', 'VBP'),
#    ('escalate', 'VB'),
#    ('issue', 'NN'),
#    ('next', 'JJ'),
#    ('level', 'NN')],
#   [('purchase', 'VBD'),
#    ('move', 'NN'),
#    ('phone', 'NN'),
#    ('low', 'JJS'),
#    ('price', 'NN')],
#   [('issue', 'NN'),
#    ('use', 'VBG'),
#    ('5', 'CD'),
#    ('6', 'CD'),
#    ('hour', 'NNS'),
#    ('automaticly', 'RB'),
#    ('switche', 'VBP'),
#    ('purchase', 'VBN'),
#    ('3', 'CD'),
#    ('mobile', 'JJ'),
#    ('phone', 'NN'),
#    ('every', 'DT'),
#    ('one', 'CD'),
#    ('get', 'VBG'),
#    ('diffrent', 'JJ'),
#    ('type', 'NN'),
#    ('issue', 'NN')],
#   [('think', 'VBP'),
#    ('phone', 'NN'),
#    ('quality', 'NN'),
#    ('issue', 'NN'),
#    ("'s", 'POS'),
#    ('amozone', 'NN'),
#    ('sale', 'NN'),
#    ('low', 'JJS'),
#    ('price', 'NN')],
#   [('perfect', 'JJ'),
#    ('blend', 'VB'),
#    ('craftsmanship', 'NN'),
#    ('durability', 'NN'),
#    ('nokia', 'NN'),
#    ('61', 'CD'),
#    ('plus', 'CC'),
#    ('gr8', 'CD'),
#    ('device', 'NN'),
#    ('indeed', 'RB')],
#   [('get', 'VBD'),
#    ('12k', 'FW'),
#    ('664gb', 'FW'),
#    ('variant', 'NN'),
#    ('really', 'RB'),
#    ('handy', 'JJ'),
#    ('device', 'NN'),
#    ('think', 'VBD'),
#    ('3050', 'CD'),
#    ('mah', 'NN'),
#    ('battery', 'NN'),
#    ('may', 'MD'),
#    ('seem', 'VB'),
#    ('little', 'JJ'),
#    ('underwhelming', 'JJ'),
#    ('device', 'NN'),
#    ('make', 'NNS'),
#    ('run', 'VBZ'),
#    ('day', 'NN'),
#    ('half', 'NN'),
#    ('moderate', 'JJ'),
#    ('usage', 'NN')],
#   [('one', 'CD'),
#    ('thing', 'NN'),
#    ('second', 'JJ'),
#    ('thought', 'NNS'),
#    ('regard', 'VBG'),
#    ('front', 'JJ'),
#    ('panel', 'NN'),
#    ('bottom', 'NN'),
#    ('brand', 'VBG'),
#    ('chin', 'NN'),
#    ('planning', 'NN'),
#    ('abandon', 'VBP'),
#    ('device', 'NN'),
#    ('bad', 'JJ'),
#    ('idea', 'NN'),
#    ('cuz', 'FW'),
#    ('u', 'FW'),
#    ('get', 'VB'),
#    ('hand', 'NN'),
#    ('device', 'NN'),
#    ('true', 'JJ'),
#    ('flagship', 'NN'),
#    ('killer', 'NN'),
#    ('look', 'VBZ'),
#    ('really', 'RB'),
#    ('premium', 'JJ')],
#   [('able', 'JJ'),
#    ('start', 'NN'),
#    ('mobile', 'JJ'),
#    ('since', 'IN'),
#    ('unpack', 'VBG'),
#    ('box', 'NN'),
#    ('2days', 'NNS'),
#    ('request', 'VBP'),
#    ('take', 'VB'),
#    ('back', 'RP'),
#    ('mobile', 'JJ')],
#   [('bad', 'JJ'),
#    ('experience', 'NN'),
#    ('mobile', 'JJ'),
#    ('come', 'VBD'),
#    ('without', 'IN'),
#    ('software', 'NN')],
#   [('switching', 'NN'),
#    ('mobile', 'JJ'),
#    ('asking', 'NN'),
#    ('system', 'NN'),
#    ('update', 'VBP'),
#    ('download', 'NN')],
#   [('wifi', 'NNS'),
#    ('download', 'NN'),
#    ('complete', 'VBZ'),
#    ('say', 'VBZ'),
#    ('installation', 'NN'),
#    ('problem', 'NN')],
#   [('working', 'NN'),
#    ("'m", 'VBP'),
#    ('unable', 'JJ'),
#    ('use', 'NN'),
#    ("'s", 'POS'),
#    ('start', 'VBG')],
#   [('awesome', 'JJ'),
#    ('phone', 'NN'),
#    ('use', 'VBN'),
#    ('xiomi', 'FW'),
#    ('vivo', 'FW'),
#    ('nothing', 'NN'),
#    ('beat', 'NN'),
#    ('nokia', 'NN'),
#    ("'s", 'POS'),
#    ('quality', 'NN'),
#    ("'s", 'POS'),
#    ('still', 'RB'),
#    ('best', 'RB'),
#    ('handy', 'JJ'),
#    ('mobile', 'JJ'),
#    ('also', 'RB'),
#    ('get', 'VB'),
#    ('earphone', 'NNS'),
#    ('company', 'NNS'),
#    ('stop', 'VBD'),
#    ('give', 'VBG')],
#   [('guy', 'NNS'),
#    ('risk', 'NN'),
#    ('buy', 'NN'),
#    ('productas', 'NNS'),
#    ('receive', 'VBD'),
#    ('totally', 'RB'),
#    ('defective', 'JJ'),
#    ('productit', 'NN'),
#    ('get', 'VBG'),
#    ('heated', 'JJ'),
#    ('charging', 'NN'),
#    ('also', 'RB'),
#    ('get', 'VBG'),
#    ('hangedthe', 'JJ'),
#    ('important', 'JJ'),
#    ('thing', 'NN'),
#    ('accept', 'VBG'),
#    ('pin', 'NN'),
#    ('set', 'NN'),
#    ('phone', 'NN'),
#    ('get', 'VBG'),
#    ('reset', 'JJ'),
#    ('commandthe', 'JJ'),
#    ('command', 'NN'),
#    ('window', 'NN'),
#    ('available', 'JJ')],
#   [('nokia', 'NN'),
#    ('61', 'CD'),
#    ('4gb', 'JJ'),
#    ('ram', 'NN'),
#    ('64', 'CD'),
#    ('gb', 'NN'),
#    ('memory', 'NN'),
#    ('storage', 'NN'),
#    ('61', 'CD'),
#    ('plus', 'CC'),
#    ('nokia', 'NN'),
#    ('drop', 'VBD'),
#    ("'s", 'POS'),
#    ('hardware', 'NN'),
#    ('quality', 'NN'),
#    ('6gb', 'JJ'),
#    ('ram', 'NN'),
#    ('performance', 'NN'),
#    ('degrade', 'VBD'),
#    ('compare', 'VBN'),
#    ('4gb', 'JJ'),
#    ('ram', 'NN'),
#    ('nokia', 'NN'),
#    ('61', 'CD')],
#   [('excellent', 'JJ')],
#   [('phone', 'NN'),
#    ('perfect', 'JJ'),
#    ('serve', 'VBZ'),
#    ('purpose', 'NN'),
#    ('since', 'IN'),
#    ('call', 'VBG'),
#    ('whatsapp', 'JJ'),
#    ('usage', 'NN'),
#    ('happy', 'JJ'),
#    ('performance', 'NN'),
#    ('phone', 'NN'),
#    ('time', 'NN'),
#    ('delivery', 'NN'),
#    ('receive', 'VBD'),
#    ('sealed', 'JJ'),
#    ('box', 'NN'),
#    ('overall', 'JJ'),
#    ('good', 'JJ'),
#    ('experience', 'NN'),
#    ('flipkart', 'NN'),
#    ('seller', 'NN'),
#    ('nokia', 'VBD')],
#   [('another', 'DT'),
#    ('premium', 'NN'),
#    ('product', 'NN'),
#    ('nokia', 'NN'),
#    ('build', 'VBP'),
#    ('quality', 'NN'),
#    ('look', 'VBZ'),
#    ('superb', 'JJ'),
#    ('stock', 'NN'),
#    ('android', 'NN'),
#    ('clean', 'JJ'),
#    ('interface', 'NN'),
#    ('like', 'IN'),
#    ('customise', 'VBN'),
#    ('android', 'NN'),
#    ('interface', 'NNS'),
#    ('add', 'VBZ'),
#    ('bag', 'VBN'),
#    ('amazing', 'JJ'),
#    ('deal', 'NN'),
#    ('prime', 'JJ'),
#    ('day', 'NNS'),
#    ('overall', 'JJ'),
#    ('experience', 'NN'),
#    ('phone', 'NN'),
#    ('awesome', 'JJ'),
#    ('price', 'NN'),
#    ('band', 'NN'),
#    ('thanks', 'NNS'),
#    ('amazon', 'VBP'),
#    ('deliver', 'VBG'),
#    ('day', 'NN'),
#    ('almost', 'RB'),
#    ('hat', 'NNS')],
#   [('great', 'RB'),
#    ('phone', 'VBP'),
#    ('highly', 'RB'),
#    ('handy', 'JJ'),
#    ('fit', 'NNS'),
#    ('well', 'RB'),
#    ('hand', 'VBP'),
#    ('camera', 'NN'),
#    ('good', 'JJ'),
#    ('battery', 'NN'),
#    ('last', 'VBZ'),
#    ('day', 'NN'),
#    ('half', 'JJ'),
#    ('nokia', 'NN'),
#    ('really', 'RB'),
#    ('good', 'JJ'),
#    ('still', 'RB')],
#   [('first', 'JJ'), ('overview', 'NN'), ('product', 'NN')],
#   [('one', 'CD'),
#    ('word', 'NN'),
#    ("'s", 'POS'),
#    ('classy', 'JJ'),
#    ('premium', 'NN'),
#    ('class', 'NN'),
#    ('metalic', 'JJ'),
#    ('damn', 'NN'),
#    ('sexy', 'JJ')],
#   [('second', 'JJ'), ('thing', 'NN'), ('performance', 'NN')],
#   [('end', 'NN'),
#    ('game', 'NNS'),
#    ('still', 'RB'),
#    ("n't", 'RB'),
#    ('find', 'VBD'),
#    ('single', 'JJ'),
#    ('lagin', 'JJ'),
#    ('one', 'NN'),
#    ("'s", 'POS'),
#    ('buttersmooth', 'NN'),
#    ('creamy', 'JJ'),
#    ('never', 'RB'),
#    ('make', 'VB'),
#    ('u', 'NN'),
#    ('feel', 'NN'),
#    ('like', 'IN'),
#    ('lag', 'NN'),
#    ('hang', 'VBP'),
#    ('issue', 'NN'),
#    ('highly', 'RB'),
#    ('recommend', 'VBD'),
#    ('gamers', 'NNS')],
#   [('never', 'RB'),
#    ('mind', 'VBP'),
#    ('heating', 'NN'),
#    ('issue', 'NN'),
#    ('issue', 'NN'),
#    ('wheb', 'NN'),
#    ('multitasking', 'VBG'),
#    ('play', 'NN'),
#    ('game', 'NNS'),
#    ('2', 'CD'),
#    ('hour', 'NN'),
#    ('battery', 'NN'),
#    ('board', 'NN'),
#    ('start', 'VBZ'),
#    ('heat', 'NN'),
#    ('produce', 'VBP'),
#    ('energysome', 'JJ'),
#    ('mobile', 'NNS'),
#    ('panel', 'NN'),
#    ('wo', 'MD'),
#    ("n't", 'RB'),
#    ('show', 'VB'),
#    ("'s", 'POS'),
#    ('glass', 'NN'),
#    ('make', 'VBD'),
#    ('back', 'JJ'),
#    ('door', 'NN'),
#    ('reflect', 'VBZ'),
#    ('transparently', 'RB'),
#    ('safe', 'JJ'),
#    ('becaus', 'NN'),
#    ("'s", 'POS'),
#    ('store', 'VBG'),
#    ('head', 'NN'),
#    ('inside', 'IN'),
#    ('within', 'IN'),
#    ('2', 'CD'),
#    ('5', 'CD'),
#    ('minute', 'NNS'),
#    ('come', 'VBP'),
#    ('normal', 'JJ'),
#    ('temperature', 'NN'),
#    ('brand', 'NN'),
#    ('spoiler', 'NNS'),
#    ('post', 'VBP'),
#    ('like', 'IN'),
#    ('battery', 'NN'),
#    ('issue', 'NN'),
#    ('heating', 'NN'),
#    ('issue', 'NN'),
#    ('please', 'VBP'),
#    ("n't", 'RB'),
#    ('trust', 'NN'),
#    ('u', 'NN'),
#    ('trust', 'NN'),
#    ('single', 'JJ'),
#    ('common', 'JJ'),
#    ('heat', 'NN'),
#    ('also', 'RB'),
#    ('seem', 'VBZ'),
#    ('like', 'IN'),
#    ('heavy', 'JJ'),
#    ('one', 'CD')],
#   [('battery', 'NN'), ('backup', 'NN'), ('performance', 'NN')],
#   [('really', 'RB'),
#    ('happy', 'JJ'),
#    ('battery', 'NN'),
#    ('backup', 'NN'),
#    ('see', 'VBP'),
#    ('use', 'NN'),
#    ('upto', 'NN'),
#    ('10', 'CD'),
#    ('hour', 'NNS'),
#    ('screen', 'NN'),
#    ('upto', 'NN'),
#    ('2', 'CD'),
#    ('3', 'CD'),
#    ('day', 'NNS'),
#    ('idle', 'VBP'),
#    ('charge', 'VBG'),
#    ('flawless', 'JJ'),
#    ('awesome', 'JJ'),
#    ('fully', 'RB'),
#    ('charge', 'VBN'),
#    ('device', 'NN'),
#    ('1hour', 'NN'),
#    ('40', 'CD'),
#    ('minute', 'NNS'),
#    ('mobile', 'JJ'),
#    ('switch', 'VBN'),
#    ('take', 'VBZ'),
#    ('223', 'CD'),
#    ('hour', 'NNS'),
#    ('chargei', 'NNS'),
#    ('mean', 'VBP'),
#    ('quick', 'JJ'),
#    ('charge', 'NN'),
#    ('work', 'VBZ'),
#    ('mobile', 'JJ'),
#    ('turnd', 'NN')],
#   [('try', 'VB'),
#    ('18w', 'FW'),
#    ('charger', 'FW'),
#    ('good', 'JJR'),
#    ('battery', 'NN'),
#    ('life', 'NN')],
#   [('one', 'CD'),
#    ('word', 'NN'),
#    ("'s", 'POS'),
#    ('awesome', 'JJ'),
#    ('juice', 'NN'),
#    ('drink', 'NN'),
#    ('fir', 'NN'),
#    ('whole', 'JJ'),
#    ('day', 'NN')],
#   [('camera', 'NN'), ('clearity', 'NN')],
#   [('excited', 'JJ'),
#    ('image', 'NN'),
#    ('shoot', 'VBD'),
#    ('perfect', 'JJ'),
#    ('lighting', 'NN'),
#    ('perfect', 'JJ'),
#    ('balance', 'NN'),
#    ('nearly', 'RB'),
#    ('25', 'CD'),
#    ('mb', 'NN'),
#    ("'s", 'POS'),
#    ('crisp', 'JJ'),
#    ('clear', 'JJ'),
#    ('awesome', 'JJ'),
#    ('picture', 'NN'),
#    ('see', 'VB'),
#    ('detail', 'NNS'),
#    ('everything', 'NN'),
#    ('inever', 'RB'),
#    ('see', 'VBN'),
#    ('type', 'NN'),
#    ('clear', 'JJ'),
#    ('picture', 'NN'),
#    ('mobile', 'JJ'),
#    ('camera', 'NN'),
#    ('low', 'JJ'),
#    ('light', 'NN'),
#    ("'s", 'POS'),
#    ('damn', 'NN'),
#    ('bad', 'JJS'),
#    ('ever', 'RB'),
#    ('camera', 'NN'),
#    ('reason', 'NN'),
#    ('hardware', 'NN'),
#    ("'s", 'POS'),
#    ('software', 'NN'),
#    ('soon', 'RB'),
#    ('solve', 'VBD'),
#    ('thus', 'RB'),
#    ('world', 'NN'),
#    ('bi', 'IN'),
#    ('perfect', 'JJ'),
#    ('phone', 'NN'),
#    ('range', 'NN'),
#    ("n't", 'RB'),
#    ('expect', 'VB'),
#    ('mobile', 'JJ')],
#   [('overall', 'NN'),
#    ("'s", 'POS'),
#    ('best', 'JJS'),
#    ('steal', 'VBP'),
#    ('awesome', 'JJ'),
#    ('stuff', 'NN'),
#    ('ever', 'RB'),
#    ('price', 'NN'),
#    ('range', 'NN'),
#    ("'s", 'POS'),
#    ('unimaginable', 'JJ')],
#   [('go', 'NN')],
#   [("'ve", 'VBP'),
#    ('use', 'VBN'),
#    ('phone', 'NN'),
#    ('almost', 'RB'),
#    ('month', 'NN'),
#    ('would', 'MD'),
#    ('certainly', 'RB'),
#    ('recommend', 'VBN'),
#    ('gaming', 'NN'),
#    ('due', 'JJ'),
#    ('heating', 'NN'),
#    ('issue', 'NNS'),
#    ('battery', 'NN'),
#    ('drain', 'NN'),
#    ('camera', 'NN'),
#    ('light', 'VBD'),
#    ('ui', 'NN'),
#    ('also', 'RB'),
#    ('amazing', 'JJ'),
#    ("'s", 'POS'),
#    ('little', 'JJ'),
#    ('problem', 'NN'),
#    ('installation', 'NN'),
#    ('process', 'NN'),
#    ('phone', 'VBP'),
#    ("n't", 'RB'),
#    ('complete', 'JJ'),
#    ('unless', 'IN'),
#    ('really', 'RB'),
#    ('fast', 'JJ'),
#    ('internet', 'NN'),
#    ('connection', 'NN'),
#    ('battery', 'NN'),
#    ('performance', 'NN'),
#    ('bad', 'JJ'),
#    ('charged', 'JJ'),
#    ('use', 'NN'),
#    ('23', 'CD'),
#    ('day', 'NNS'),
#    ('use', 'VBP'),
#    ('wisely', 'RB'),
#    ('require', 'VBN'),
#    ('stuff', 'NNS'),
#    ('without', 'IN'),
#    ('play', 'VBG'),
#    ('high', 'JJ'),
#    ('load', 'NN'),
#    ('game', 'NNS'),
#    ('surf', 'VBG'),
#    ('social', 'JJ'),
#    ('medium', 'NNS'),
#    ('day', 'NN'),
#    ('battery', 'NN'),
#    ("n't", 'RB'),
#    ('last', 'JJ'),
#    ('20', 'CD'),
#    ('hour', 'NNS'),
#    ('always', 'RB'),
#    ('keep', 'VBP'),
#    ('internet', 'NN'),
#    ('normal', 'JJ'),
#    ('genuine', 'JJ'),
#    ('phone', 'NN'),
#    ('user', 'NN'),
#    ("'s", 'POS'),
#    ('awesome', 'JJ'),
#    ('phone', 'NN'),
#    ("'s", 'POS'),
#    ('processor', 'NN'),
#    ('also', 'RB'),
#    ('quite', 'RB'),
#    ('fast', 'RB'),
#    ('look', 'VBZ'),
#    ('amazing', 'JJ'),
#    ('look', 'NNS'),
#    ('like', 'IN'),
#    ('delicate', 'JJ'),
#    ('phone', 'NN'),
#    ('metallic', 'JJ'),
#    ('body', 'NN'),
#    ('side', 'NNS'),
#    ('gorilla', 'NN'),
#    ('glass', 'NN'),
#    ('plane', 'NNS'),
#    ('overall', 'NN'),
#    ("'s", 'POS'),
#    ('nice', 'JJ'),
#    ('phone', 'NN'),
#    ('would', 'MD'),
#    ("n't", 'RB'),
#    ('recommend', 'VB'),
#    ('gamers', 'NNS'),
#    ('day', 'NN'),
#    ('smartphone', 'NN'),
#    ('addict', 'NNS'),
#    ('battery', 'NN'),
#    ('drain', 'NN'),
#    ('else', 'RB'),
#    ("'s", 'VBZ'),
#    ('amazing', 'JJ')],
#   [("'s", 'POS'),
#    ('6', 'CD'),
#    ('hour', 'NNS'),
#    ("'m", 'VBP'),
#    ('try', 'VBG'),
#    ('install', 'VB'),
#    ('app', 'NN'),
#    ("'s", 'POS'),
#    ('respond', 'VBG'),
#    ('mobile', 'JJ'),
#    ('data', 'NNS'),
#    ('wifi', 'VBP'),
#    ('nothing', 'NN'),
#    ('seem', 'VBZ'),
#    ('work', 'NN'),
#    ('none', 'NN'),
#    ('apps', 'NNS'),
#    ('get', 'VBG'),
#    ('update', 'VBN'),
#    ('ca', 'MD'),
#    ("n't", 'RB'),
#    ('download', 'VB'),
#    ('new', 'JJ'),
#    ('apps', 'NNS'),
#    ('phone', 'NN'),
#    ('plzz', 'NN'),
#    ("n't", 'RB'),
#    ('buy', 'VB'),
#    ('product', 'NN')],
#   [("'re", 'VBP'),
#    ('go', 'VBG'),
#    ('buy', 'JJ'),
#    ('phone', 'NN'),
#    ('buy', 'NN'),
#    ('type', 'NN'),
#    ('c', 'NN'),
#    ('cable', 'NN'),
#    ('charge', 'VBG'),
#    ('port', 'NN'),
#    ('get', 'VBG'),
#    ('loose', 'JJ'),
#    ('day', 'NNS'),
#    ("'s", 'POS'),
#    ('well', 'RBR'),
#    ('buy', 'VB'),
#    ('magnatic', 'JJ'),
#    ('type', 'NN'),
#    ('c', 'NN'),
#    ('cable', 'NN'),
#    ('please', 'VBP'),
#    ('go', 'VB'),
#    ('online', 'JJ'),
#    ('review', 'NNS'),
#    ('buy', 'VBG'),
#    ('camera', 'NN'),
#    ('performance', 'NN'),
#    ('good', 'JJ'),
#    ('instal', 'VBG'),
#    ('gcam', 'NN'),
#    ('app', 'NN'),
#    ('music', 'NN'),
#    ('experience', 'NN'),
#    ('good', 'JJ'),
#    ('speaker', 'NN'),
#    ('35', 'CD'),
#    ('mm', 'NN'),
#    ('head', 'NN'),
#    ('jack', 'NN'),
#    ('disturbance', 'NNS'),
#    ('get', 'VBP'),
#    ('listen', 'VBG'),
#    ('perfectly', 'RB'),
#    ('suit', 'VBZ'),
#    ('normal', 'JJ'),
#    ('daily', 'JJ'),
#    ('usage', 'NN'),
#    ('heavy', 'JJ'),
#    ('user', 'NNS')],
#   [('enclose', 'VBG'),
#    ('image', 'NNS'),
#    ('take', 'VBN'),
#    ('realme', 'VBP'),
#    ('1st', 'JJ'),
#    ('version', 'NN'),
#    ('1st', 'JJ'),
#    ('photo', 'NN'),
#    ('v', 'CC'),
#    ('nokia', 'NN'),
#    ('61', 'CD'),
#    ('plus', 'CC'),
#    ('image', 'NN'),
#    ('2nd', 'JJ'),
#    ('image', 'NN'),
#    ('photo', 'NN'),
#    ('take', 'VBN'),
#    ('nokia', 'NN'),
#    ('61', 'CD'),
#    ('plus', 'CC'),
#    ('dull', 'JJ'),
#    ('compare', 'VBN'),
#    ('old', 'JJR'),
#    ('phone', 'NN')],
#   [('deliver', 'VBN'),
#    ('today', 'NN'),
#    ('surprise', 'VBD'),
#    ('see', 'VB'),
#    ('black', 'JJ'),
#    ('defective', 'JJ'),
#    ('screen', 'NN')],
#   [('receive', 'VBD'),
#    ('defective', 'JJ'),
#    ('item', 'NN'),
#    ('mobile', 'JJ'),
#    ('charging', 'NN'),
#    ('switch', 'VBD'),
#    ('start', 'VBG'),
#    ('follow', 'VBG'),
#    ('amazon', 'NN'),
#    ('last', 'JJ'),
#    ('5', 'CD'),
#    ('day', 'NNS'),
#    ('replacement', 'NN'),
#    ('pathetic', 'JJ'),
#    ('service', 'NNS'),
#    ('amazon', 'VBP'),
#    ('care', 'VBG'),
#    ('prime', 'JJ'),
#    ('customer', 'NN'),
#    ('also', 'RB')],
#   [('caution', 'VBP'),
#    ('dont', 'JJ'),
#    ('buy', 'NN'),
#    ('major', 'JJ'),
#    ('major', 'JJ'),
#    ('heating', 'NN'),
#    ('issue', 'NN'),
#    ('even', 'RB'),
#    ('10', 'CD'),
#    ('minute', 'JJ'),
#    ('speaker', 'NN'),
#    ('call', 'NN'),
#    ('become', 'VBZ'),
#    ('uncomfortable', 'JJ'),
#    ('hold', 'NN'),
#    ('battery', 'NN'),
#    ('poor', 'JJ'),
#    ('dat', 'NN'),
#    ('u', 'NN'),
#    ('habit', 'NN'),
#    ('keep', 'VBG'),
#    ('net', 'JJ'),
#    ('ur', 'NN'),
#    ('phone', 'NN'),
#    ('probably', 'RB'),
#    ('would', 'MD'),
#    ('need', 'VB'),
#    ('twice', 'RB'),
#    ('full', 'JJ'),
#    ('charge', 'VBG'),
#    ('day', 'NN'),
#    ('dat', 'NN'),
#    ('like', 'IN'),
#    ('pathetic', 'JJ'),
#    ('look', 'NNS'),
#    ('r', 'NN'),
#    ('everything', 'NN'),
#    ('least', 'JJS'),
#    ('shud', 'JJ'),
#    ('work', 'NN'),
#    ('like', 'IN'),
#    ('nrml', 'JJ'),
#    ('phone', 'NN')],
#   [('look', 'NN'),
#    ('awesome', 'JJ'),
#    ('af', 'IN'),
#    ('6', 'CD'),
#    ('gb', 'NN'),
#    ('ram', 'NN'),
#    ('11999', 'CD'),
#    ('great', 'JJ')],
#   [('micro', 'JJ'),
#    ('phone', 'NN'),
#    ('complaint', 'NN'),
#    ('nokia', 'NN'),
#    ('company', 'NN'),
#    ('give', 'VBP'),
#    ('replacement', 'NN'),
#    ('model', 'NN'),
#    ('repair', 'NN'),
#    ('mean', 'VBZ'),
#    ('company', 'NN'),
#    ('already', 'RB'),
#    ('know', 'VBP'),
#    ('problematic', 'JJ'),
#    ('model', 'NN'),
#    ('complaint', 'NN'),
#    ('show', 'VBN'),
#    ('32st', 'JJ'),
#    ('day', 'NN'),
#    ('date', 'NN'),
#    ('invoice', 'NN'),
#    ('amazon', 'NN'),
#    ('accept', 'VBD'),
#    ('return', 'NN')],
#   [('incoming', 'JJ'),
#    ('call', 'NNS'),
#    ('ring', 'VBG'),
#    ('properly', 'RB'),
#    ('show', 'NNS'),
#    ('miss', 'VBD'),
#    ('call', 'NNS'),
#    ('without', 'IN'),
#    ('ring', 'VBG'),
#    ('torch', 'NN'),
#    ('without', 'IN'),
#    ('command', 'NN'),
#    ('think', 'VBP'),
#    ('work', 'VBG'),
#    ('normal', 'JJ'),
#    ('smartphone', 'NNS'),
#    ('think', 'VBP'),
#    ('manufacture', 'VBG'),
#    ('defect', 'NNS'),
#    ('smartphone', 'RB'),
#    ('please', 'VBP'),
#    ('help', 'NN'),
#    ('remove', 'VB'),
#    ('problem', 'NNS')],
#   [('waste', 'NN'),
#    ('money', 'NN'),
#    ('camera', 'NN'),
#    ('good', 'JJ'),
#    ('heating', 'NN'),
#    ('problem', 'NN')],
#   [('â', 'NN'),
#    ('buy', 'VBD'),
#    ('15th', 'JJ'),
#    ('july', 'NNP'),
#    ('week', 'NN'),
#    ('start', 'VBD'),
#    ('face', 'VBG'),
#    ('auto', 'NN'),
#    ('restart', 'VBP'),
#    ('issue', 'NN'),
#    ('get', 'VB'),
#    ('check', 'VBN'),
#    ('nokia', 'NNS'),
#    ('care', 'VBP'),
#    ('26th', 'JJ'),
#    ('july', 'NNP'),
#    ('update', 'VBN'),
#    ('software', 'NN'),
#    ('30', 'CD'),
#    ('min', 'NN'),
#    ('face', 'VBD'),
#    ('similar', 'JJ'),
#    ('issue', 'NNS'),
#    ('next', 'IN'),
#    ('10', 'CD'),
#    ('day', 'NNS'),
#    ('analysis', 'NN'),
#    ('find', 'VBD'),
#    ('issue', 'NNS'),
#    ('suggest', 'VBN'),
#    ('take', 'VBP'),
#    ('delivery', 'NN'),
#    ('mobile', 'JJ'),
#    ('10th', 'JJ'),
#    ('august', 'NNP'),
#    ('next', 'JJ'),
#    ('day', 'NN'),
#    ('see', 'VBN'),
#    ('similar', 'JJ'),
#    ('issue', 'NN'),
#    ('submit', 'VBD'),
#    ('nokia', 'NN'),
#    ('care', 'NN'),
#    ('16', 'CD'),
#    ('th', 'DT'),
#    ('august', 'NNP'),
#    ('time', 'NN'),
#    ('another', 'DT'),
#    ('update', 'VBP'),
#    ('software', 'NN'),
#    ('work', 'VBD'),
#    ('fine', 'JJ'),
#    ('issue', 'NN'),
#    ('still', 'RB'),
#    ('submit', 'VBD'),
#    ('17th', 'JJ'),
#    ('aug', 'NN'),
#    ('wait', 'VBG'),
#    ('fix', 'NN'),
#    ('brand', 'NN'),
#    ('new', 'JJ'),
#    ('device', 'NN')],
#   [('battey', 'NN'),
#    ('would', 'MD'),
#    ('good', 'JJR'),
#    ('performance', 'NN'),
#    ('ok', 'FW'),
#    ('ok', 'FW'),
#    ('application', 'NN'),
#    ('like', 'IN'),
#    ('phone', 'NN'),
#    ('pe', 'FW'),
#    ('whatsapp', 'FW'),
#    ('build', 'VBN'),
#    ('message', 'NN'),
#    ('app', 'NN'),
#    ('hang', 'VBZ'),
#    ('restart', 'VB'),
#    ('app', 'NN'),
#    ('serval', 'JJ'),
#    ('time', 'NNS'),
#    ('even', 'RB'),
#    ('mobile', 'JJ'),
#    ('6', 'CD'),
#    ('gb', 'FW'),
#    ('ram', 'FW'),
#    ('build', 'VB'),
#    ('quality', 'NN'),
#    ('look', 'NNS'),
#    ('touch', 'RB'),
#    ('screen', 'VBP'),
#    ('awesome', 'JJ'),
#    ('voice', 'NN'),
#    ('call', 'VBG'),
#    ('speaker', 'NN'),
#    ('ok', 'FW'),
#    ('ok', 'FW')],
#   [('phone', 'NN'),
#    ('heating', 'NN'),
#    ('issue', 'NN'),
#    ('well', 'RB'),
#    ('take', 'VBZ'),
#    ('3', 'CD'),
#    ('hr', 'NN'),
#    ('fully', 'RB'),
#    ('charge', 'VBD'),
#    ('2', 'CD'),
#    ('percent', 'NN'),
#    ('95', 'CD'),
#    ('percent', 'NN')],
#   [('inbox', 'FW'),
#    ('headphone', 'FW'),
#    ('bad', 'JJS'),
#    ('quality', 'NN'),
# ...
#   [('6', 'CD'), ('good', 'JJ'), ('look', 'NNS')],
#   [('7', 'CD'), ('handy', 'JJ'), ('phone', 'NN'), ('big', 'JJ')],
#   [('con', 'NNS')],
#   [('non', 'JJ')],
#   [('use', 'VBG'),
#    ('pixel', 'NN'),
#    ('say', 'VBP'),
#    ('performance', 'NN'),
#    ('phone', 'NN'),
#    ('par', 'NN'),
#    ('even', 'RB'),
#    ('good', 'JJR'),
#    ('pixel', 'NN'),
#    ('except', 'IN'),
#    ('camera', 'NN'),
#    ('build', 'VBP'),
#    ('superb', 'JJ'),
#    ('clean', 'JJ'),
#    ('android', 'NN'),
#    ('experience', 'NN'),
#    ('work', 'VBZ'),
#    ('like', 'IN'),
#    ('butter', 'NN'),
#    ('100', 'CD'),
#    ('apps', 'NNS'),
#    ('long', 'RB'),
#    ('run', 'VBP'),
#    ('battery', 'NN'),
#    ('life', 'NN'),
#    ('may', 'MD'),
#    ('concern', 'VB'),
#    ('u', 'NN'),
#    ('expect', 'VBP'),
#    ('11k', 'NN'),
#    ('product', 'NN')],
#   [('camera', 'NN'), ('quality', 'NN'), ('bad', 'JJS')],
#   [('great', 'JJ'),
#    ('look', 'VBG'),
#    ('phone', 'NN'),
#    ('premium', 'NN'),
#    ('glass', 'NN'),
#    ('finish', 'NN'),
#    ('back', 'RB'),
#    ('come', 'VBZ'),
#    ('android', 'NN'),
#    ('9', 'CD'),
#    ('pie', 'NN'),
#    ('android', 'NN'),
#    ('one', 'CD'),
#    ('ui', 'NN'),
#    ('rare', 'JJ'),
#    ('phone', 'NNS'),
#    ('price', 'NN'),
#    ('range', 'NN'),
#    ('late', 'JJS'),
#    ('feature', 'NNS'),
#    ('capability', 'NNS'),
#    ('camera', 'NN'),
#    ('seem', 'VBZ'),
#    ('decent', 'JJ'),
#    ("n't", 'RB'),
#    ('test', 'VBN'),
#    ('different', 'JJ'),
#    ('condition', 'NNS'),
#    ('audio', 'NN'),
#    ('video', 'NN'),
#    ('quality', 'NN'),
#    ('mark', 'NN'),
#    ('charging', 'NN'),
#    ('could', 'MD'),
#    ('fast', 'JJR')],
#   [('mark', 'NN'),
#    ('phone', 'NN'),
#    ('get', 'VBG'),
#    ('heat', 'NN'),
#    ('whike', 'NN'),
#    ('use', 'VBG'),
#    ('expect', 'VBN'),
#    ('nokia', 'JJ'),
#    ('tried', 'JJ'),
#    ('contact', 'NN'),
#    ('customer', 'NN'),
#    ('care', 'NN'),
#    ('return', 'NN'),
#    ('try', 'VBG'),
#    ('convince', 'VBP'),
#    ('retain', 'VB'),
#    ('handset', 'NN'),
#    ('pay', 'VBG'),
#    ('11k', 'NN'),
#    ('totally', 'RB'),
#    ('waste', 'NN'),
#    ('im', 'NN'),
#    ('trap', 'NN'),
#    ("n't", 'RB'),
#    ('know', 'VB'),
#    ('whether', 'IN'),
#    ('return', 'NN')],
#   [('6gb', 'JJ'),
#    ('bol', 'NN'),
#    ('kar', 'FW'),
#    ('4bg', 'FW'),
#    ('de', 'FW'),
#    ('gye', 'FW'),
#    ('good', 'JJ')],
#   [('pro', 'NNS')],
#   [('1', 'CD'), ('look', 'VBZ'), ('good', 'JJ')],
#   [('2', 'CD'), ('screen', 'NN'), ('good', 'NN')],
#   [('3', 'CD'), ('android', 'VBD'), ('one', 'CD')],
#   [('4', 'CD'), ('6gb', 'JJ'), ('ram', 'NN')],
#   [('con', 'NNS')],
#   [('1', 'CD'), ('bad', 'JJ'), ('camera', 'NN'), ('quality', 'NN')],
#   [('2', 'CD'),
#    ('phone', 'NN'),
#    ('respond', 'VBZ'),
#    ('often', 'RB'),
#    ('need', 'VBZ'),
#    ('restart', 'VB'),
#    ('lot', 'NN'),
#    ('sw', 'NN'),
#    ('issue', 'NNS')],
#   [('3', 'CD'),
#    ('use', 'VBG'),
#    ('nokia', 'JJ'),
#    ('charging', 'NN'),
#    ('cable', 'NN'),
#    ('phone', 'NN'),
#    ('heat', 'VBZ'),
#    ('happen', 'VB'),
#    ('sonysamsung', 'JJ'),
#    ('type', 'NN'),
#    ('c', 'NN'),
#    ('cable', 'NN'),
#    ('nokia', 'NN'),
#    ('charger', 'NN'),
#    ('sure', 'JJ'),
#    ('cause', 'NNS'),
#    ('charge', 'VBG'),
#    ('port', 'NN'),
#    ('problem', 'NN')],
#   [('overall', 'JJ'),
#    ('ok', 'FW'),
#    ('10k', 'FW'),
#    ('offer', 'NN'),
#    ('price', 'NN')],
#   [('purchase', 'VBD'),
#    ('phone', 'NN'),
#    ('month', 'NN'),
#    ('back', 'RB'),
#    ('far', 'RB'),
#    ("n't", 'RB'),
#    ('encounter', 'VBD'),
#    ('performance', 'NN'),
#    ('issue', 'NNS'),
#    ('camera', 'NN'),
#    ('sensor', 'NNS'),
#    ('good', 'JJ'),
#    ('nokia', 'NN'),
#    ("'s", 'POS'),
#    ('camera', 'NN'),
#    ('app', 'NN'),
#    ('disappointing', 'JJ'),
#    ('used', 'JJ'),
#    ('moded', 'JJ'),
#    ('google', 'NN'),
#    ('cam', 'FW'),
#    ('app', 'FW'),
#    ('quality', 'NN'),
#    ('image', 'NNS'),
#    ('take', 'VBN'),
#    ('improve', 'VBD'),
#    ('10', 'CD'),
#    ('time', 'NNS'),
#    ('felt', 'VBD'),
#    ('customize', 'VBG'),
#    ('o', 'IN'),
#    ('setting', 'NNS'),
#    ('less', 'RBR'),
#    ('convenient', 'JJ'),
#    ('nokia', 'NN'),
#    ('61', 'CD'),
#    ('nokia', 'NN'),
#    ('62017', 'CD'),
#    ('though', 'IN'),
#    ('run', 'VBG'),
#    ('android', 'NN'),
#    ('pie', 'NN'),
#    ('minimal', 'JJ'),
#    ('change', 'NNS')],
#   [('overall', 'JJ'),
#    ('value', 'NN'),
#    ('money', 'NN'),
#    ('want', 'VBP'),
#    ('use', 'NN'),
#    ('power', 'NN'),
#    ('user', 'NN'),
#    ('might', 'MD'),
#    ('need', 'VB'),
#    ('tweak', 'JJ'),
#    ('thing', 'NNS')],
#   [('phone', 'NN'),
#    ('segment', 'NN'),
#    ('configuration', 'NN'),
#    ('beauty', 'NN'),
#    ('stock', 'NN'),
#    ('android', 'NN'),
#    ('battery', 'NN'),
#    ("n't", 'RB'),
#    ('drain', 'VB'),
#    ('easily', 'RB'),
#    ('use', 'VBG'),
#    ('phone', 'NN'),
#    ('camera', 'NN'),
#    ('quality', 'NN'),
#    ('ok', 'IN')],
#   [('phone', 'NN'),
#    ('glass', 'NN'),
#    ('hence', 'RB'),
#    ('little', 'JJ'),
#    ('bit', 'NN'),
#    ('slippery', 'JJ'),
#    ('use', 'VBG'),
#    ('back', 'NN'),
#    ('cover', 'NN')],
#   [("'m", 'VBP'),
#    ('use', 'VBG'),
#    ('month', 'NN'),
#    ('good', 'JJ'),
#    ('fast', 'JJ'),
#    ('response', 'NN'),
#    ('amazing', 'JJ'),
#    ('spec', 'NNS'),
#    ("'m", 'VBP'),
#    ('run', 'VBG'),
#    ('pubg', 'NN'),
#    ('comfortably', 'RB'),
#    ('lag', 'VBP'),
#    ('good', 'JJ'),
#    ('sensitivity', 'NN'),
#    ('good', 'JJ'),
#    ('volume', 'NN'),
#    ('camera', 'NN'),
#    ('average', 'JJ')],
#   [('nice', 'JJ'),
#    ('phone', 'NN'),
#    ('price', 'NN'),
#    ('r', 'FW'),
#    ('11000', 'FW'),
#    ('depend', 'VBZ'),
#    ('completely', 'RB'),
#    ('seller', 'NN'),
#    ('sell', 'VBG'),
#    ('damage', 'VBN'),
#    ('article', 'NN'),
#    ('cell', 'NN'),
#    ('sell', 'VBD'),
#    ('amazon', 'NN'),
#    ("'s", 'POS'),
#    ('basically', 'RB'),
#    ('seller', 'NN'),
#    ('cell', 'NN'),
#    ('perfectly', 'RB'),
#    ('fine', 'JJ'),
#    ('talk', 'VBG'),
#    ('camera', 'NN'),
#    ('rom', 'NN'),
#    ('ram', 'NN'),
#    ('little', 'JJ'),
#    ('bit', 'NN'),
#    ('heating', 'NN'),
#    ('problem', 'NN'),
#    ('else', 'JJ'),
#    ('everything', 'NN'),
#    ('fine', 'NN')],
#   [('thing', 'NN'),
#    ('point', 'NN'),
#    ("'s", 'POS'),
#    ('battery', 'NN'),
#    ('small', 'JJ'),
#    ('664', 'CD'),
#    ('mobile', 'JJ'),
#    ('3k', 'NN'),
#    ('something', 'NN'),
#    ('wise', 'JJ'),
#    ("'s", 'POS'),
#    ('best', 'JJS'),
#    ('phone', 'NN'),
#    ('ever', 'RB'),
#    ('stunning', 'JJ'),
#    ('graphic', 'NNS'),
#    ('high', 'JJ'),
#    ('speed', 'NN'),
#    ('processer', 'NN'),
#    ('6gb', 'JJ'),
#    ('ram', 'NN')],
#   [('also', 'RB'),
#    ('forget', 'VBP'),
#    ('second', 'JJ'),
#    ('sim', 'NN'),
#    ('memory', 'NN'),
#    ('card', 'NN'),
#    ('putt', 'VBD'),
#    ('time', 'NN'),
#    ('64gb', 'JJ'),
#    ('memory', 'NN'),
#    ('help', 'NN'),
#    ('additional', 'JJ'),
#    ('memory', 'NN'),
#    ('require', 'VBD')],
#   [('qwic', 'JJ'),
#    ('lock', 'NN'),
#    ('work', 'VBG'),
#    ('time', 'NNS'),
#    ('hang', 'VBG'),
#    ('voice', 'NN'),
#    ('recorder', 'NN'),
#    ('call', 'NN'),
#    ('recorder', 'NN'),
#    ('look', 'VBG'),
#    ('good', 'JJ'),
#    ('featucher', 'NN'),
#    ('worest', 'NN'),
#    ('amazone', 'NN'),
#    ('sirvice', 'NN'),
#    ('good', 'JJ'),
#    ('iam', 'NN'),
#    ('tlaking', 'NN'),
#    ('2', 'CD'),
#    ('time', 'NNS'),
#    ('refund', 'NN'),
#    ('money', 'NN'),
#    ('issu', 'FW'),
#    ('custmor', 'FW'),
#    ('support', 'NN'),
#    ('team', 'NN'),
#    ('answar', 'JJ'),
#    ('happy', 'JJ')],
#   [('performance', 'NN'), ('good', 'JJ')],
#   [('compact', 'JJ'), ('design', 'NN')],
#   [('stock', 'NN'), ('andriod', 'NN')],
#   [('look', 'VBG'), ('phone', 'NN'), ('12k', 'NN'), ('go', 'VB')],
#   [('nice', 'JJ'), ('phone', 'NN')],
#   [('nothing', 'NN'), ('dislike', 'NN')],
#   [('customer', 'NNS'),
#    ('complain', 'VBG'),
#    ('body', 'NN'),
#    ('heating', 'NN')],
#   [('personally', 'RB'),
#    ('think', 'VBP'),
#    ('every', 'DT'),
#    ('phone', 'NN'),
#    ('heating', 'NN'),
#    ('issue', 'NN')],
#   [('nothing', 'NN'), ('worry', 'VBP')],
#   [("n't", 'RB'),
#    ('charge', 'NN'),
#    ('phone', 'NN'),
#    ('2', 'CD'),
#    ('hour', 'NNS')],
#   [('increase', 'VBP'), ('phone', 'NNS'), ('battery', 'NN'), ('life', 'NN')],
#   [('excellent', 'JJ'), ('mobilenice', 'NN'), ('grip', 'NN')],
#   [('slim', 'JJ'),
#    ('design', 'NN'),
#    ('quality', 'NN'),
#    ('look', 'VBG'),
#    ('wise', 'JJ'),
#    ('good', 'JJ')],
#   [('best', 'JJS'), ('performance', 'NN')],
#   [('6gb', 'JJ'), ('64gb', 'JJ'), ('problem', 'NN')],
#   [('thanks', 'NNS'), ('amazon', 'FW'), ('nokia', 'FW')],
#   [('draw', 'NN'), ('back', 'RB')],
#   [('face', 'VBP'), ('unlock', 'NN')],
#   [],
#   [('hybrid', 'NN'), ('system', 'NN')],
#   [('single', 'JJ'),
#    ('sim', 'NN'),
#    ('memory', 'NN'),
#    ('card', 'NN'),
#    ('dual', 'JJ'),
#    ('sim', 'NN'),
#    ('without', 'IN'),
#    ('memory', 'NN'),
#    ('card', 'NN')],
#   [('battery', 'NN'), ('backup100100', 'NN')],
#   [('believe', 'VBP'),
#    ('nokia', 'NNS'),
#    ('always', 'RB'),
#    ('serve', 'VBP'),
#    ('quality', 'NN'),
#    ('product', 'NNS'),
#    ('happy', 'JJ'),
#    ('nokia', 'NN'),
#    ('51', 'CD'),
#    ('plus', 'CC'),
#    ('nokia', 'NN'),
#    ('61', 'CD'),
#    ('plus', 'CC'),
#    ('operate', 'VBG'),
#    ('system', 'NN'),
#    ('need', 'VBZ'),
#    ('drastic', 'JJ'),
#    ('change', 'NNS'),
#    ('initial', 'JJ'),
#    ('update', 'VB'),
#    ('take', 'VBD'),
#    ('almost', 'RB'),
#    ('whole', 'JJ'),
#    ('night', 'NN'),
#    ('google', 'NN'),
#    ('whether', 'IN'),
#    ('widget', 'NNS'),
#    ('home', 'NN'),
#    ('screen', 'NN'),
#    ('cant', 'NN'),
#    ('remove', 'VBD'),
#    ('browse', 'FW'),
#    ('apps', 'FW'),
#    ('swipe', 'NN'),
#    ('home', 'NN'),
#    ('button', 'NN'),
#    ('show', 'VBZ'),
#    ('task', 'NN'),
#    ('killer', 'NN'),
#    ('first', 'RB'),
#    ('annoy', 'VBG'),
#    ('first', 'JJ'),
#    ('thing', 'NNS'),
#    ('notice', 'VBD'),
#    ('two', 'CD'),
#    ('day', 'NNS'),
#    ('use', 'VBP'),
#    ('come', 'VBG'),
#    ('look', 'NN'),
#    ('thats', 'VBZ'),
#    ('premium', 'JJ'),
#    ('handy', 'JJ')],
#   [('nokia', 'NN'),
#    ('lover', 'NN'),
#    ('best', 'JJS'),
#    ('phone', 'NN'),
#    ('camera', 'NN'),
#    ('average', 'JJ'),
#    ('battery', 'NN'),
#    ('life', 'NN'),
#    ('beloww', 'NN'),
#    ('average', 'NN'),
#    ('display', 'VBP'),
#    ('perfectlook', 'JJ'),
#    ('feel', 'NN'),
#    ('goodin11000rs', 'NNS'),
#    ('phone', 'VBP'),
#    ('beststock', 'JJ'),
#    ('android', 'NN'),
#    ('experience', 'NN'),
#    ('best', 'RB'),
#    ('nokia', 'RB'),
#    ('give', 'VB'),
#    ('regular', 'JJ'),
#    ('update', 'NNS'),
#    ('pie', 'NN'),
#    ('update', 'VBP'),
#    ('google', 'NN'),
#    ('assistant', 'NN'),
#    ('voice', 'NN'),
#    ('unlock', 'NN'),
#    ('workkðÿ', 'NN'),
#    ('battery', 'NN'),
#    ('life', 'NN'),
#    ('poor', 'JJ'),
#    ('killing', 'NN'),
#    ('meeðÿðÿðÿ', 'NN'),
#    ('specification', 'NNS'),
#    ('goodcharging', 'VBG'),
#    ('time', 'NN'),
#    ('2', 'CD'),
#    ('hr', 'NNS'),
#    ('time', 'NNS'),
#    ('2', 'CD'),
#    ('15hrsstill', 'NN'),
#    ('love', 'NN'),
#    ('phoneðÿ³ðÿšðÿš', 'NN')],
#   [('mobile', 'JJ'), ('deliver', 'VBN'), ('amazon', 'NN'), ('defect', 'NNS')],
#   [('defect', 'VBZ')],
#   [('1', 'CD'), ('battery', 'NN'), ('backup', 'NN'), ('good', 'NN')],
#   [('2', 'CD'), ('often', 'RB'), ('touch', 'RB'), ('recognize', 'VBN')],
#   [('3', 'CD'),
#    ('finger', 'NN'),
#    ('print', 'NN'),
#    ('performance', 'NN'),
#    ('good', 'JJ')],
#   [('phone', 'NN'),
#    ('call', 'VBG'),
#    ('charging', 'NN'),
#    ("'s", 'POS'),
#    ('battery', 'NN'),
#    ('become', 'VB'),
#    ('hotheating', 'VBG'),
#    ('phone', 'NN'),
#    ('battery', 'NN'),
#    ('take', 'VBZ'),
#    ('place', 'NN')],
#   [('unlike', 'IN'),
#    ('android', 'NN'),
#    ('device', 'NNS'),
#    ('nokia', 'NN'),
#    ('seem', 'VBZ'),
#    ('bit', 'RB'),
#    ('advanced', 'JJ'),
#    ('take', 'VBZ'),
#    ('care', 'NN'),
#    ('memory', 'NN'),
#    ('usage', 'NN'),
#    ('actssuggests', 'NNS'),
#    ('accordingly', 'RB')],
#   [('best', 'RB'),
#    ('buy', 'VB'),
#    ('office', 'NN'),
#    ('user', 'NN'),
#    ('battery', 'NN'),
#    ('awesome', 'JJ'),
#    ('even', 'RB'),
#    ('less', 'RBR'),
#    ('call', 'VBN'),
#    ('high', 'JJR'),
#    ('configuration', 'NN'),
#    ('chinese', 'JJ'),
#    ('mobile', 'NNS'),
#    ('last', 'VBZ'),
#    ('1', 'CD'),
#    ('day', 'NN'),
#    ('even', 'RB'),
#    ('70', 'CD'),
#    ('charging', 'NN'),
#    ('ad', 'NNS'),
#    ('malware', 'VBP'),
#    ('blogwar', 'JJ'),
#    ('android', 'NN'),
#    ('one', 'CD'),
#    ('no1', 'NN'),
#    ('lacuna', 'NN'),
#    ('camera', 'NN'),
#    ('upto', 'NN'),
#    ('mark', 'NN'),
#    ('day', 'NN'),
#    ('picture', 'NNS'),
#    ('great', 'JJ'),
#    ('low', 'JJ'),
#    ('light', 'JJ'),
#    ('zoom', 'NN'),
#    ('disappointing', 'JJ'),
#    ('6', 'CD'),
#    ('gb', 'FW'),
#    ('ram', 'FW'),
#    ('great', 'JJ'),
#    ('nokia', 'JJ'),
#    ('feel', 'NN'),
#    ('hand', 'NN'),
#    ('great', 'JJ')],
#   [('amazing', 'JJ'),
#    ('product', 'NN'),
#    ('nokia', 'NNS'),
#    ('still', 'RB'),
#    ('need', 'VBP'),
#    ('update', 'NNS'),
#    ('improve', 'VB'),
#    ('camera', 'NN'),
#    ('quality', 'NN'),
#    ('literally', 'RB'),
#    ('camera', 'NN'),
#    ('good', 'JJ'),
#    ('suffer', 'VBP'),
#    ('low', 'JJ'),
#    ('light', 'JJ'),
#    ('condition', 'NN'),
#    ('front', 'JJ'),
#    ('camera', 'NN'),
#    ('nice', 'JJ'),
#    ('battery', 'NN'),
#    ('much', 'RB'),
#    ('low', 'JJ'),
#    ('heavy', 'JJ'),
#    ('user', 'NN'),
#    ('face', 'NN'),
#    ('battery', 'NN'),
#    ('problem', 'NN'),
#    ('lack', 'VBP'),
#    ('heating', 'NN'),
#    ('issue', 'NN'),
#    ('day', 'NN'),
#    ('yo', 'IN'),
#    ('day', 'NN'),
#    ('use', 'VBP'),
#    ('good', 'JJ'),
#    ('picture', 'NN'),
#    ('clarity', 'NN'),
#    ('sound', 'NN'),
#    ('quality', 'NN'),
#    ('beautiful', 'JJ'),
#    ('satisfied', 'JJ')],
#   [('use', 'VBG'),
#    ('nokia', 'NN'),
#    ('6', 'CD'),
#    ('single', 'JJ'),
#    ('16mp', 'JJ'),
#    ('camera', 'NN'),
#    ('phone', 'NN'),
#    ('3', 'CD'),
#    ('gb', 'FW'),
#    ('ram', 'FW'),
#    ('internal', 'JJ'),
#    ('storage', 'NN'),
#    ('32', 'CD'),
#    ('gb', 'NN'),
#    ('buy', 'VBD'),
#    ('â¹', 'NN'),
#    ('13000', 'CD'),
#    ('since', 'IN'),
#    ('october', 'NNP'),
#    ('2017', 'CD'),
#    ('come', 'VBN'),
#    ('nokia', 'NN'),
#    ('61', 'CD'),
#    ('plus', 'CC'),
#    ('16mp', 'JJ'),
#    ('5mp', 'JJ'),
#    ('back', 'JJ'),
#    ('camera', 'NN'),
#    ('ai', 'VBP'),
#    ('bokeh', 'NN'),
#    ('mode', 'NN'),
#    ('6gb', 'JJ'),
#    ('ram', 'NN'),
#    ('64gb', 'JJ'),
#    ('internal', 'JJ'),
#    ('storage', 'NN'),
#    ('â¹', 'NN'),
#    ('10999', 'CD'),
#    ('whats', 'NNS'),
#    ('wrong', 'RB'),
#    ('deal', 'VBP'),
#    ('nokia', 'JJ')],
#   [('full', 'JJ'),
#    ('paisa', 'NN'),
#    ('vasool', 'NN'),
#    ('phone', 'NN'),
#    ('rab', 'NN')],
#   [('receive', 'VBD'), ('product', 'NN'), ('replacement', 'NN')],
#   [('open', 'VBD'),
#    ('packet', 'NN'),
#    ('notice', 'VBD'),
#    ('mobile', 'JJ'),
#    ('use', 'VBN'),
#    ('someone', 'NN'),
#    ('receive', 'VBD'),
#    ('pack', 'VBG'),
#    ('good', 'JJ'),
#    ('second', 'JJ'),
#    ('time', 'NN'),
#    ('replacement', 'NN'),
#    ('receive', 'VBD')],
#   [('switch', 'VBN'),
#    ('mobile', 'JJ'),
#    ('observed', 'JJ'),
#    ('mobile', 'JJ'),
#    ('set', 'NN'),
#    ('viberate', 'NN'),
#    ('mode', 'NN'),
#    ('instead', 'RB'),
#    ('ringtone', 'NN')],
#   [('really', 'RB'), ('disappoint', 'VBD'), ('amazon', 'NN')],
#   [('planning', 'NN'), ('return', 'NN'), ('mobile', 'JJ'), ('amazon', 'NN')],
#   [('premium', 'NN'),
#    ('thing', 'NN'),
#    ('like', 'IN'),
#    ('phone', 'NN'),
#    ('camera', 'NN'),
#    ('photo', 'NNS'),
#    ('take', 'VBN'),
#    ('really', 'RB'),
#    ('ultimate', 'JJ')],
#   [('ppl', 'NN'),
#    ('believe', 'VBP'),
#    ('rear', 'JJ'),
#    ('camera', 'NNS'),
#    ('inbuilt', 'JJ'),
#    ('video', 'NN'),
#    ('stabilization', 'NN'),
#    ('ie', 'NN'),
#    ('video', 'NN'),
#    ('capture', 'NN'),
#    ('wo', 'MD'),
#    ("n't", 'RB'),
#    ('noisy', 'VB')],
#   [('great', 'JJ'),
#    ('premium', 'NN'),
#    ('display', 'NN'),
#    ('premium', 'NN'),
#    ('design', 'NN'),
#    ('material', 'NN'),
#    ('quality', 'NN'),
#    ('also', 'RB'),
#    ('front', 'JJ'),
#    ('camera', 'NN'),
#    ('doseba', 'NN'),
#    ('great', 'JJ'),
#    ('job', 'NN')],
#   [('guy', 'NNS'),
#    ('plan', 'VBG'),
#    ('buy', 'VB'),
#    ('mid', 'JJ'),
#    ('range', 'NN'),
#    ('phone', 'NN'),
#    ('go', 'VBP'),
#    ('nokia', 'NN'),
#    ('61', 'CD'),
#    ('plus', 'CC'),
#    ('6gb', 'JJ'),
#    ('ram', 'NN'),
#    ('64', 'CD'),
#    ('gb', 'FW'),
#    ('rom', 'FW')],
#   [('best', 'JJS'), ('value', 'NN'), ('money', 'NN')],
#   [('enjoy', 'VBG'),
#    ('phone', 'NN'),
#    ('problem', 'NN'),
#    ('nd', 'NN'),
#    ("'s", 'POS'),
#    ('light', 'JJ'),
#    ('weight', 'NN'),
#    ('nd', 'NN'),
#    ('handy', 'JJ')]]}

# %%
stats_calc(review)
# Out:
# FEATURE :  phone
#     Total Reviews       :  123
#     Positive Reviews    :  0.691 %
#     Negative Reviews    :  0.138 %
#     Unclassified Reviews:  0.171 %
#
# FEATURE :  camera
#     Total Reviews       :  66
#     Positive Reviews    :  0.545 %
#     Negative Reviews    :  0.258 %
#     Unclassified Reviews:  0.197 %
#
# FEATURE :  day
#     Total Reviews       :  32
#     Positive Reviews    :  0.531 %
#     Negative Reviews    :  0.312 %
#     Unclassified Reviews:  0.156 %
#
# FEATURE :  nokia
#     Total Reviews       :  59
#     Positive Reviews    :  0.593 %
#     Negative Reviews    :  0.102 %
#     Unclassified Reviews:  0.305 %
#
# FEATURE :  battery
#     Total Reviews       :  50
#     Positive Reviews    :  0.420 %
#     Negative Reviews    :  0.400 %
#     Unclassified Reviews:  0.180 %
#
# FEATURE :  quality
#     Total Reviews       :  47
#     Positive Reviews    :  0.660 %
#     Negative Reviews    :  0.213 %
#     Unclassified Reviews:  0.128 %
#
# FEATURE :  issue
#     Total Reviews       :  22
#     Positive Reviews    :  0.636 %
#     Negative Reviews    :  0.182 %
#     Unclassified Reviews:  0.182 %
#
# FEATURE :  price
#     Total Reviews       :  31
#     Positive Reviews    :  0.613 %
#     Negative Reviews    :  0.194 %
#     Unclassified Reviews:  0.194 %
#
# FEATURE :  use
#     Total Reviews       :  34
#     Positive Reviews    :  0.559 %
#     Negative Reviews    :  0.324 %
#     Unclassified Reviews:  0.118 %
#
# FEATURE :  time
#     Total Reviews       :  18
#     Positive Reviews    :  0.444 %
#     Negative Reviews    :  0.278 %
#     Unclassified Reviews:  0.278 %
#
# FEATURE :  performance
#     Total Reviews       :  28
#     Positive Reviews    :  0.643 %
#     Negative Reviews    :  0.250 %
#     Unclassified Reviews:  0.107 %
#
# FEATURE :  amazon
#     Total Reviews       :  27
#     Positive Reviews    :  0.741 %
#     Negative Reviews    :  0.074 %
#     Unclassified Reviews:  0.185 %
#
# FEATURE :  android
#     Total Reviews       :  32
#     Positive Reviews    :  0.562 %
#     Negative Reviews    :  0.094 %
#     Unclassified Reviews:  0.344 %
#
# FEATURE :  product
#     Total Reviews       :  23
#     Positive Reviews    :  0.696 %
#     Negative Reviews    :  0.130 %
#     Unclassified Reviews:  0.174 %
#
# FEATURE :  ram
#     Total Reviews       :  26
#     Positive Reviews    :  0.423 %
#     Negative Reviews    :  0.077 %
#     Unclassified Reviews:  0.500 %
#
# FEATURE :  device
#     Total Reviews       :  13
#     Positive Reviews    :  0.615 %
#     Negative Reviews    :  0.154 %
#     Unclassified Reviews:  0.231 %
#
# FEATURE :  premium
#     Total Reviews       :  21
#     Positive Reviews    :  0.714 %
#     Negative Reviews    :  0.048 %
#     Unclassified Reviews:  0.238 %
#
# FEATURE :  problem
#     Total Reviews       :  17
#     Positive Reviews    :  0.647 %
#     Negative Reviews    :  0.176 %
#     Unclassified Reviews:  0.176 %
#
# FEATURE :  life
#     Total Reviews       :  16
#     Positive Reviews    :  0.500 %
#     Negative Reviews    :  0.375 %
#     Unclassified Reviews:  0.125 %
#
# FEATURE :  screen
#     Total Reviews       :  17
#     Positive Reviews    :  0.529 %
#     Negative Reviews    :  0.353 %
#     Unclassified Reviews:  0.118 %
#
# FEATURE :  gb
#     Total Reviews       :  19
#     Positive Reviews    :  0.632 %
#     Negative Reviews    :  0.000 %
#     Unclassified Reviews:  0.368 %
#
# FEATURE :  experience
#     Total Reviews       :  17
#     Positive Reviews    :  0.647 %
#     Negative Reviews    :  0.294 %
#     Unclassified Reviews:  0.059 %
#
# FEATURE :  return
#     Total Reviews       :  14
#     Positive Reviews    :  0.643 %
#     Negative Reviews    :  0.214 %
#     Unclassified Reviews:  0.143 %
#
# FEATURE :  hour
#     Total Reviews       :  2
#     Positive Reviews    :  0.000 %
#     Negative Reviews    :  0.000 %
#     Unclassified Reviews:  1.000 %
#
# FEATURE :  heating
#     Total Reviews       :  15
#     Positive Reviews    :  0.733 %
#     Negative Reviews    :  0.200 %
#     Unclassified Reviews:  0.067 %
#
# FEATURE :  glass
#     Total Reviews       :  12
#     Positive Reviews    :  0.750 %
#     Negative Reviews    :  0.083 %
#     Unclassified Reviews:  0.167 %
#
# FEATURE :  design
#     Total Reviews       :  14
#     Positive Reviews    :  0.786 %
#     Negative Reviews    :  0.000 %
#     Unclassified Reviews:  0.214 %
#
# FEATURE :  usage
#     Total Reviews       :  12
#     Positive Reviews    :  0.500 %
#     Negative Reviews    :  0.500 %
#     Unclassified Reviews:  0.000 %
#
# FEATURE :  thing
#     Total Reviews       :  8
#     Positive Reviews    :  0.500 %
#     Negative Reviews    :  0.250 %
#     Unclassified Reviews:  0.250 %
#
# FEATURE :  app
#     Total Reviews       :  14
#     Positive Reviews    :  0.286 %
#     Negative Reviews    :  0.429 %
#     Unclassified Reviews:  0.286 %
#
# FEATURE :  replacement
#     Total Reviews       :  10
#     Positive Reviews    :  0.800 %
#     Negative Reviews    :  0.200 %
#     Unclassified Reviews:  0.000 %
#
# FEATURE :  range
#     Total Reviews       :  13
#     Positive Reviews    :  0.615 %
#     Negative Reviews    :  0.231 %
#     Unclassified Reviews:  0.154 %
#
# FEATURE :  sim
#     Total Reviews       :  7
#     Positive Reviews    :  0.429 %
#     Negative Reviews    :  0.286 %
#     Unclassified Reviews:  0.286 %
#
# FEATURE :  purchase
#     Total Reviews       :  9
#     Positive Reviews    :  0.667 %
#     Negative Reviews    :  0.111 %
#     Unclassified Reviews:  0.222 %
#
# FEATURE :  display
#     Total Reviews       :  13
#     Positive Reviews    :  0.846 %
#     Negative Reviews    :  0.154 %
#     Unclassified Reviews:  0.000 %
#
# FEATURE :  photo
#     Total Reviews       :  3
#     Positive Reviews    :  0.667 %
#     Negative Reviews    :  0.000 %
#     Unclassified Reviews:  0.333 %
#
# FEATURE :  feature
#     Total Reviews       :  6
#     Positive Reviews    :  0.667 %
#     Negative Reviews    :  0.333 %
#     Unclassified Reviews:  0.000 %
#
# FEATURE :  brand
#     Total Reviews       :  8
#     Positive Reviews    :  0.500 %
#     Negative Reviews    :  0.375 %
#     Unclassified Reviews:  0.125 %
#
# FEATURE :  people
#     Total Reviews       :  9
#     Positive Reviews    :  0.778 %
#     Negative Reviews    :  0.111 %
#     Unclassified Reviews:  0.111 %
#
# FEATURE :  stock
#     Total Reviews       :  11
#     Positive Reviews    :  0.455 %
#     Negative Reviews    :  0.000 %
#     Unclassified Reviews:  0.545 %
#
# FEATURE :  picture
#     Total Reviews       :  4
#     Positive Reviews    :  1.000 %
#     Negative Reviews    :  0.000 %
#     Unclassified Reviews:  0.000 %
#
# FEATURE :  memory
#     Total Reviews       :  8
#     Positive Reviews    :  0.625 %
#     Negative Reviews    :  0.250 %
#     Unclassified Reviews:  0.125 %
#
# FEATURE :  image
#     Total Reviews       :  3
#     Positive Reviews    :  0.000 %
#     Negative Reviews    :  0.667 %
#     Unclassified Reviews:  0.333 %
#
# FEATURE :  call
#     Total Reviews       :  6
#     Positive Reviews    :  0.500 %
#     Negative Reviews    :  0.167 %
#     Unclassified Reviews:  0.333 %
#
# FEATURE :  model
#     Total Reviews       :  7
#     Positive Reviews    :  0.714 %
#     Negative Reviews    :  0.143 %
#     Unclassified Reviews:  0.143 %
#
# FEATURE :  seller
#     Total Reviews       :  6
#     Positive Reviews    :  0.500 %
#     Negative Reviews    :  0.333 %
#     Unclassified Reviews:  0.167 %
#
# FEATURE :  hand
#     Total Reviews       :  10
#     Positive Reviews    :  0.600 %
#     Negative Reviews    :  0.400 %
#     Unclassified Reviews:  0.000 %
#
# FEATURE :  software
#     Total Reviews       :  9
#     Positive Reviews    :  0.333 %
#     Negative Reviews    :  0.111 %
#     Unclassified Reviews:  0.556 %
#
# FEATURE :  option
#     Total Reviews       :  8
#     Positive Reviews    :  0.750 %
#     Negative Reviews    :  0.125 %
#     Unclassified Reviews:  0.125 %
#
# FEATURE :  pro
#     Total Reviews       :  3
#     Positive Reviews    :  0.333 %
#     Negative Reviews    :  0.667 %
#     Unclassified Reviews:  0.000 %

# %%
import json
out_file_name = input_add.split('.')[0] + '_summary.json'
with open(out_file_name, 'w') as json_file:
  json.dump(review['feature_summary'], json_file)

out_file_name = input_add.split('.')[0] + '_opinion_dictionary.json'
with open(out_file_name, 'w') as json_file:
  json.dump(review['opinion_dictionary'], json_file)

out_file_name = input_add.split('.')[0] + '_opinion_dictionary_tagged.json'
with open(out_file_name, 'w') as json_file:
  json.dump(review['opinion_dictionary_tagged'], json_file)
